# %%
# Todo
#1.Remove भोकणे and सुरुवात

# %%
# Import and schema setup
# - Removes part_of_speech
# - Adds entry_id
# - Adds entry_type
# - Adds base_word (for collocations)
# - Adds search_text

import json
from collections import OrderedDict
from copy import deepcopy

# Load the dictionary
with open('berntsen_dictionary.json', 'r', encoding='utf-8') as f:
    original_data = json.load(f)

print(f"Loaded {len(original_data)} entries")

# Create new data with proper field ordering
data = []
for entry in original_data:
    # Create new ordered dictionary with entry_id first
    new_entry = OrderedDict()
    new_entry['entry_id'] = f"berntsen_{entry['headword_devanagari']}_{entry['source_page']}"
    new_entry['entry_type'] = 'headword'  # default; collocations created separately
    # Note: part_of_speech field is intentionally not included (removed)
    # Note: definitions[] added in next cell by parse_definitions()
    # Note: base_word will be set for collocations only
    new_entry['headword_devanagari'] = entry['headword_devanagari']
    new_entry['headword_romanized'] = entry['headword_romanized']
    new_entry['full_entry'] = entry['full_entry']
    new_entry['source_page'] = entry['source_page']
    new_entry['base_word'] = None
    # Note: search_text computed at end
    new_entry['search_text'] = None
    
    data.append(new_entry)

# Verify the result
print(f"\nProcessed {len(data)} entries")
print("\nExample entry (index 300):")
print(json.dumps(data[300], ensure_ascii=False, indent=2))
# Out:
# Loaded 9836 entries
#
# Processed 9836 entries
#
# Example entry (index 300):
# {
#   "entry_id": "berntsen_अवलंबून_5",
#   "entry_type": "headword",
#   "headword_devanagari": "अवलंबून",
#   "headword_romanized": "avalambūna",
#   "full_entry": "अवलंबून avalambūna , असणे asaṇē to be dependent on.",
#   "source_page": 5,
#   "base_word": null,
#   "search_text": null
# }

# %%
#Berntsen Dictionary, how part of speech is represented
# Pattern 1: Sequential POS sections (most common)
#       form: headword romanized POS1 definition(s). POS2 definition(s).
#       example: "अति ati adv. too much. pref. extremely, too much, over-."
#       description: Each POS gets its own definition section which is separated by periods
# Pattern 2: Numbered definitions within same POS
#       form: headword romanized POS 1. def1. 2. def2. 3. def3.
#       example: "अंक aṅka m. 1. number. 2. issue (of a magazine, newspaper). 3. act (of a play)."
#       description: Numbers belong to the SAME POS. All numbered definitions share the first POS mentioned
# Pattern 3: Mixed - numbered defs THEN new POS
#       form: headword romanized POS1 1. def1. 2. def2. POS2 def3.
#       example: "अखंड akhaṇḍa adj. inv. 1. entire, in one piece. 2. continuous. adv. continuously."
#       explanation of example: Definitions 1 and 2 belong to adj. inv. 
#       When adv. appears, it starts a NEW section with its own definition

# %%
#definitions[]
import re
from collections import OrderedDict

def parse_definitions(entry):
    """
    Parse the full_entry to extract definitions with their POS and numbers.
    
    Args:
        entry: Dictionary containing 'full_entry', 'headword_romanized'
    
    Returns:
        List of definition dictionaries with 'definition', 'pos_display', 'number',
        'pos', 'gender', 'declension_class', 'referenced_entry'
    """
    full_entry = entry['full_entry']
    romanized = entry['headword_romanized']
    
    # Step 1: Extract the definition part (everything after romanized headword)
    parts = full_entry.split(romanized, 1)
    if len(parts) <= 1:
        # Edge case: romanized not found, return empty
        return []
    
    definition_text = parts[1].strip()
    
    # If definition_text starts with comma, remove it
    if definition_text.startswith(','):
        definition_text = definition_text[1:].strip()
    
    # If there's no text at all, return empty
    if not definition_text:
        return []
    
    # Step 2: Define all possible POS markers (order matters - longest first to avoid partial matches)
    # IMPORTANT: Include both "v. t." and "v.t." formats
    pos_markers = [
        'adj. inv.', 'adv. suff.', 'adj. suff. inv.', 'adj. suff.',
        'n. suff.', 'n.suff.', 'm. suff.', 'f. suff.', 
        'v. t.', 'v. i.', 'v.i.', 'v.t.',  # Added both formats with and without space
        'adj.', 'adv.', 'pref.', 'suff.',
        'conj.', 'post.', 'pron.', 'interj.', 'poss.',
        'f.(i)', 'f.(e)', 'm.(i)', 'm.(e)',
        'n.', 'm.', 'f.'
    ]
    
    # Step 3: Find all POS markers and their positions in the text
    pos_locations = []
    for pos in pos_markers:
        # Find all occurrences of this POS marker
        index = 0
        while True:
            index = definition_text.find(pos, index)
            if index == -1:
                break
            # Check if this is at the start or preceded by space/period
            if index == 0 or definition_text[index-1] in [' ', '.']:
                # Check if followed by space or end of string
                end_index = index + len(pos)
                if end_index >= len(definition_text) or definition_text[end_index] == ' ':
                    pos_locations.append({
                        'pos_display': pos,
                        'start': index,
                        'end': end_index
                    })
            index += 1
    
    # Sort by position
    pos_locations.sort(key=lambda x: x['start'])
    
    # Step 4: If no POS found, treat entire text as definition with null POS
    if not pos_locations:
        # Remove trailing period
        cleaned_text = definition_text.strip()
        if cleaned_text.endswith('.'):
            cleaned_text = cleaned_text[:-1].strip()
        
        if cleaned_text:
            return [{
                'definition': cleaned_text,
                'pos_display': None,
                'number': None,
                'pos': None,
                'gender': None,
                'declension_class': None,
                'referenced_entry': None
            }]
        else:
            return []
    
    # Step 5: Split text into sections by POS
    definitions = []
    
    for i, pos_info in enumerate(pos_locations):
        current_pos = pos_info['pos_display']
        start = pos_info['end']
        
        # Find where this POS section ends (where next POS starts, or end of text)
        if i + 1 < len(pos_locations):
            end = pos_locations[i + 1]['start']
        else:
            end = len(definition_text)
        
        # Extract the definition text for this POS
        section_text = definition_text[start:end].strip()
        
        # Step 6: Check if this section has numbered definitions (1., 2., 3., etc.)
        numbered_pattern = r'(\d+)\.\s*([^0-9]+?)(?=\s*\d+\.|$)'
        numbered_matches = list(re.finditer(numbered_pattern, section_text))
        
        if numbered_matches:
            # Parse numbered definitions
            for match in numbered_matches:
                number = int(match.group(1))
                def_text = match.group(2).strip()
                
                # Clean up: remove trailing period if present
                if def_text.endswith('.'):
                    def_text = def_text[:-1].strip()
                
                # Skip empty definitions
                if def_text:
                    definitions.append({
                        'definition': def_text,
                        'pos_display': current_pos,
                        'number': number,
                        'pos': None,
                        'gender': None,
                        'declension_class': None,
                        'referenced_entry': None
                    })
        else:
            # No numbers - this is a single unnumbered definition
            # Clean the section text
            section_text = section_text.strip()
            
            # Remove trailing period
            if section_text.endswith('.'):
                section_text = section_text[:-1].strip()
            
            # Skip empty definitions
            if section_text:
                definitions.append({
                    'definition': section_text,
                    'pos_display': current_pos,
                    'number': None,
                    'pos': None,
                    'gender': None,
                    'declension_class': None,
                    'referenced_entry': None
                })
    
    return definitions


# Add definitions to all entries
for entry in data:
    entry['definitions'] = parse_definitions(entry)

# Calculate metrics
total_entries = len(data)
entries_with_defs = sum(1 for entry in data if entry['definitions'])
entries_without_defs = total_entries - entries_with_defs
total_defs = sum(len(e['definitions']) for e in data)
entries_with_null_pos = sum(1 for entry in data if entry['definitions'] and any(d['pos_display'] is None for d in entry['definitions']))

print(f"Total entries: {total_entries}")
print(f"Entries with definitions: {entries_with_defs} ({entries_with_defs/total_entries*100:.1f}%)")
print(f"Entries without definitions: {entries_without_defs} ({entries_without_defs/total_entries*100:.1f}%)")
print(f"Entries with null POS: {entries_with_null_pos} ({entries_with_null_pos/total_entries*100:.1f}%)")
print(f"Total definitions parsed: {total_defs}")
print(f"Average definitions per entry: {total_defs/total_entries:.2f}")
# Out:
# Total entries: 9836
# Entries with definitions: 9836 (100.0%)
# Entries without definitions: 0 (0.0%)
# Entries with null POS: 348 (3.5%)
# Total definitions parsed: 12167
# Average definitions per entry: 1.24

# %%
from collections import Counter

# Count POS frequency across all definitions
pos_counter = Counter()

for entry in data:
    for definition in entry['definitions']:
        pos = definition['pos_display']
        pos_counter[pos] += 1

# Sort by frequency (descending)
sorted_pos = sorted(pos_counter.items(), key=lambda x: x[1], reverse=True)

print("POS FREQUENCY DISTRIBUTION")
print("=" * 80)
print(f"Total unique POS values: {len(pos_counter)}")
print(f"Total definitions: {sum(pos_counter.values())}")
print("\n")

# Display all POS with their frequencies
for pos, count in sorted_pos:
    percentage = (count / sum(pos_counter.values())) * 100
    pos_display = f"'{pos}'" if pos is not None else "None (no POS)"
    print(f"{pos_display:30s} {count:6d} ({percentage:5.2f}%)")
# Out:
# POS FREQUENCY DISTRIBUTION
# ================================================================================
# Total unique POS values: 18
# Total definitions: 12167
#
#
# 'm.'                             3051 (25.08%)
# 'adj.'                           2219 (18.24%)
# 'f.'                             1632 (13.41%)
# 'n.'                             1583 (13.01%)
# 'v.i.'                            780 ( 6.41%)
# 'v.t.'                            745 ( 6.12%)
# 'f.(i)'                           672 ( 5.52%)
# 'adv.'                            525 ( 4.31%)
# None (no POS)                     348 ( 2.86%)
# 'f.(e)'                           207 ( 1.70%)
# 'post.'                           123 ( 1.01%)
# 'suff.'                           103 ( 0.85%)
# 'pref.'                            90 ( 0.74%)
# 'pron.'                            31 ( 0.25%)
# 'interj.'                          29 ( 0.24%)
# 'conj.'                            23 ( 0.19%)
# 'poss.'                             5 ( 0.04%)
# 'v. t.'                             1 ( 0.01%)

# %%
#Normalizing the one entry that is 'v. t.' to 'v.t.' 

for entry in data:
    for definition in entry['definitions']:
        if definition['pos_display'] == 'v. t.':
            definition['pos_display'] = 'v.t.'

# %%
# POS Mapping:
# m. → noun.masculine
# f. → noun.feminine
# f.(i) → noun.feminine.i
# f.(e) → noun.feminine.e
# n. → noun.neuter
# v.t. → verb.transitive
# v.i. → verb.intransitive
# adj. → adjective
# adj. inv. → adjective.invariable
# adv. → adverb
# post. → postposition
# pref. → prefix
# suff. → suffix
# conj. → conjunction
# pron. → pronoun
# interj. → interjection
# poss. → possessive

for entry in data:
    for definition in entry['definitions']:
        pos_display = definition.get('pos_display') or definition.get('pos')
        
        # Map to new pos format
        if pos_display == 'm.':
            definition['pos'] = 'noun.masculine'
            definition['gender'] = 'masculine'
            definition['declension_class'] = None
        elif pos_display == 'f.':
            definition['pos'] = 'noun.feminine'
            definition['gender'] = 'feminine'
            definition['declension_class'] = None
        elif pos_display == 'f.(i)':
            definition['pos'] = 'noun.feminine.i'
            definition['gender'] = 'feminine'
            definition['declension_class'] = 'i'
        elif pos_display == 'f.(e)':
            definition['pos'] = 'noun.feminine.e'
            definition['gender'] = 'feminine'
            definition['declension_class'] = 'e'
        elif pos_display == 'n.':
            definition['pos'] = 'noun.neuter'
            definition['gender'] = 'neuter'
            definition['declension_class'] = None
        elif pos_display == 'v.t.':
            definition['pos'] = 'verb.transitive'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'v.i.':
            definition['pos'] = 'verb.intransitive'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'adj.':
            definition['pos'] = 'adjective'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'adj. inv.':
            definition['pos'] = 'adjective.invariable'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'adv.':
            definition['pos'] = 'adverb'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'post.':
            definition['pos'] = 'postposition'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'pref.':
            definition['pos'] = 'prefix'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'suff.':
            definition['pos'] = 'suffix'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'conj.':
            definition['pos'] = 'conjunction'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'pron.':
            definition['pos'] = 'pronoun'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'interj.':
            definition['pos'] = 'interjection'
            definition['gender'] = None
            definition['declension_class'] = None
        elif pos_display == 'poss.':
            definition['pos'] = 'possessive'
            definition['gender'] = None
            definition['declension_class'] = None
        else:
            definition['pos'] = None
            definition['gender'] = None
            definition['declension_class'] = None

# %%
## Classification of All 948 Entries

#| Category | Count (approx) | Action | `entry_type` | Needs `referenced_entry`? |
#|----------|----------------|--------|--------------|---------------------------|
#| **A. Cross-references** ("See X") | ~50 | Keep as-is, add relationship | `headword` | Yes: `relationship: 'cross_reference'` |
#| **B. Collocations** (० patterns) | ~400 | Create NEW entries | `collocation` | No - uses `base_word` instead |
#| **C. Grammatical forms** (perf. of, past tense of, etc.) | ~40 | Add referenced_entry | `headword` | Yes: `relationship: 'base_form'` |
#| **D. Reduplication** (redupl. of) | ~20 | Add referenced_entry | `headword` | Yes: `relationship: 'reduplication_of'` |
#| **E. Abbreviations** (abbrev. of) | ~15 | Add referenced_entry | `headword` | Yes: `relationship: 'abbreviation_of'` |
#| **F. Variants** (var. of) | ~5 | Add referenced_entry | `headword` | Yes: `relationship: 'variant_of'` |
#| **G. Self-contained definitions** (measurements, cultural terms, suffixes, intensifiers, etc.) | ~400+ | No structural change | `headword` | No - Devanagari is just part of definition text |

# %%
import re

def extract_see_reference(definition_text):
    """Extract the Devanagari word that follows 'See' in a definition"""
    # Look for Devanagari characters after "See"
    match = re.search(r'See\s+([\u0900-\u097F]+)', definition_text)
    if match:
        return match.group(1)
    return None

# Add inline see_also definitions
failures = []

for entry in data:
    for definition in entry['definitions']:
        see_ref = extract_see_reference(definition['definition'])
        if see_ref:
            # Look up by DEVANAGARI headword, not romanized
            referenced_entry = next((e for e in data 
                                    if e['headword_devanagari'] == see_ref), None)
            
            if referenced_entry:
                # Successful lookup - embed the entire entry
                definition['see_also'] = {
                    'entry_id': referenced_entry['entry_id'],
                    'headword_devanagari': referenced_entry['headword_devanagari'],
                    'headword_romanized': referenced_entry['headword_romanized'],
                    'full_entry': referenced_entry['full_entry'],
                    'source_page': referenced_entry['source_page'],
                    'definitions': referenced_entry['definitions']
                }
            else:
                # Lookup failed
                definition['see_also'] = None
                failures.append({
                    'entry': entry['headword_devanagari'],
                    'romanized': entry['headword_romanized'],
                    'looking_for': see_ref,
                    'definition': definition['definition']
                })
        else:
            definition['see_also'] = None

# Report results
total_see_refs = sum(1 for e in data for d in e['definitions'] 
                     if 'See' in d['definition'])
successful = sum(1 for e in data for d in e['definitions'] 
                 if d.get('see_also') is not None)

print(f"Total 'See' references found: {total_see_refs}")
print(f"Successfully resolved: {successful}")
print(f"Failed lookups: {len(failures)}")

if failures:
    print("\n⚠️ FAILED LOOKUPS:")
    print("=" * 80)
    for f in failures:
        print(f"\nEntry: {f['entry']} ({f['romanized']})")
        print(f"Looking for: '{f['looking_for']}'")
        print(f"Definition: {f['definition']}")
# Out:
# Total 'See' references found: 92
# Successfully resolved: 87
# Failed lookups: 3
#
# ⚠️ FAILED LOOKUPS:
# ================================================================================
#
# Entry: भागुबाई (bhāgubāī)
# Looking for: 'मित्री'
# Definition: See मित्री भागुबाई
#
# Entry: भोकणे (bhōkaṇē)
# Looking for: 'भुकंणे'
# Definition: See भुकंणे
#
# Entry: सुरुवात (suruvāta)
# Looking for: 'सुरवात'
# Definition: See सुरवात

# %%
# Fixing Edge case
bhagubai_entry = next((e for e in data if e['headword_devanagari'] == 'भागुबाई'), None)
bhitri_entry = next((e for e in data if e['headword_devanagari'] == 'भित्री'), None)

if bhagubai_entry and bhitri_entry:
    # Point भागुबाई to भित्री (which has the actual definition)
    bhagubai_entry['definitions'][0]['see_also'] = {
        'entry_id': bhitri_entry['entry_id'],
        'headword_devanagari': bhitri_entry['headword_devanagari'],
        'headword_romanized': bhitri_entry['headword_romanized'],
        'full_entry': bhitri_entry['full_entry'],
        'source_page': bhitri_entry['source_page'],
        'definitions': bhitri_entry['definitions']
    }
    print("✓ Fixed भागुबाई see_also reference to भित्री")
else:
    print("✗ Could not find one of the entries")
# Out:
# ✓ Fixed भागुबाई see_also reference to भित्री

# %%
import re

# Find all definitions containing Devanagari script
devanagari_pattern = re.compile(r'[\u0900-\u097F]+')

entries_with_devanagari = []

for entry in data:
    for definition in entry['definitions']:
        if devanagari_pattern.search(definition['definition']):
            entries_with_devanagari.append({
                'headword': entry['headword_devanagari'],
                'romanized': entry['headword_romanized'],
                'definition': definition['definition'],
                'pos': definition['pos']
            })

print(f"Total definitions with Devanagari: {len(entries_with_devanagari)}")
print("\n" + "=" * 80)
print("DEFINITIONS CONTAINING DEVANAGARI SCRIPT:")
print("=" * 80)

for i, item in enumerate(entries_with_devanagari, 1):
    print(f"\n{i}. {item['headword']} ({item['romanized']})")
    print(f"   POS: {item['pos']}")
    print(f"   Definition: {item['definition']}")
# Out:
# Total definitions with Devanagari: 948
#
# ================================================================================
# DEFINITIONS CONTAINING DEVANAGARI SCRIPT:
# ================================================================================
#
# 1. अखेर (akhēra)
#    POS: adverb
#    Definition: finally. ० चे final
#
# 2. अंग (aṅga)
#    POS: noun.neuter
#    Definition: capacity, skill. ० चे natural, inborn. ० चोरणे to contract one's body, shirk. ० धरणे to have rheumatic pains, gain weight. ० वळणी असणे to be used to. अंगात येणे to be possessed (by a god, evil spirit)
#
# 3. अग्रक्रम (agrakrama)
#    POS: noun.masculine
#    Definition: priority. अग्रक्रमाने giving priority, primarily
#
# 4. अट (aṭa)
#    POS: noun.feminine.i
#    Definition: condition, stipulation. ० घालणे to make a condition
#
# 5. अट्टाहास (aṭṭāhāsa)
#    POS: noun.masculine
#    Definition: obstinacy, dogmatic claim. ० बाळगणे , धरणे to be obstinate, make a dogmatic claim
#
# 6. अंत (anta)
#    POS: noun.masculine
#    Definition: end, death. ० पाहणे to try one's patience
#
# 7. अंतर (antara)
#    POS: noun.neuter
#    Definition: distance. ० तोडणे to cover a distance. ० देणे to part from, leave, abandon
#
# 8. अदपाव (adapāva)
#    POS: None
#    Definition: one-eighth of a शेर or kilo
#
# 9. अद्दल (addala)
#    POS: noun.feminine.i
#    Definition: punishment. ० घडणे to be punished
#
# 10. अद्वैत (advaita)
#    POS: noun.neuter
#    Definition: non-duality, the doctrine that the आत्मा and ब्रह्म are one
#
# 11. अनंत (ananta)
#    POS: adjective
#    Definition: inv. without end अनंतापर्यत्न forever
#
# 12. अन्न (anna)
#    POS: noun.neuter
#    Definition: food. अन्नास जागणे to remain loyal to a benefactor out of gratitude
#
# 13. अलीकडे (alīkaḍē)
#    POS: None
#    Definition: See अलिकडे
#
# 14. अवतरण (avataraṇa)
#    POS: noun.neuter
#    Definition: quotation. ० चिन्हे quotation marks
#
# 15. अवलंबून (avalambūna)
#    POS: None
#    Definition: असणे asaṇē to be dependent on
#
# 16. असेना (asēnā)
#    POS: None
#    Definition: का kā so what
#
# 17. अहमहमिका (ahamahamikā)
#    POS: noun.feminine
#    Definition: competition. ० लागणे for a competition to start. ० करणे to compete
#
# 18. अक्षर (akṣara)
#    POS: adjective
#    Definition: inv. indestructible. ० वाङ्मय classical literature
#
# 19. आ (ā)
#    POS: None
#    Definition: करणे karaṇē to open one's mouth (to say `ah')
#
# 20. आकार (ākāra)
#    POS: noun.masculine
#    Definition: shape, size. ० घेणे , येणे to take shape. ० देणे to give shape
#
# 21. आकुंचन (ākuñcana)
#    POS: noun.neuter
#    Definition: contraction. ० होणे , ० पावणे to contract
#
# 22. आखडते (ākhaḍatē)
#    POS: adjective
#    Definition: contracted. हात आखडता घेणे to stop giving, restrain oneself. (esp. with regard to spending)
#
# 23. आग्रह (āgraha)
#    POS: noun.masculine
#    Definition: insistence, insistent urging. ० करणे to urge
#
# 24. आंघोळ (āṅghōḷa)
#    POS: noun.feminine.i
#    Definition: bath. ० करणे to take a bath. ० घालणे to bathe (another)
#
# 25. आजारी (ājārī)
#    POS: adjective
#    Definition: inv. ill, sick. ० पडणे to fall ill
#
# 26. आटपाट (āṭapāṭa)
#    POS: None
#    Definition: नगर nagara a big town
#
# 27. आटापिटा (āṭāpiṭā)
#    POS: noun.masculine
#    Definition: great effort. जिवाचा ० करणे to do one's utmost
#
# 28. आटोपणे (āṭōpaṇē)
#    POS: None
#    Definition: See आटपणे
#
# 29. आठवण (āṭhavaṇa)
#    POS: noun.feminine.i
#    Definition: memory, recollection. ० होणे to remember. ० करणे to remember, remind
#
# 30. आठी (āṭhī)
#    POS: noun.feminine
#    Definition: wrinkle of brow, frown. ० पडणे , पाडणे , घालणे to frown
#
# 31. आड (āḍa)
#    POS: adverb
#    Definition: in the way. ० येणे to come in the way of
#
# 32. आढी (āḍhī)
#    POS: noun.feminine
#    Definition: packing of fruit in layers in straw to facilitate ripening. ० लावणे , घालणे to pack fruit in layers
#
# 33. आण (āṇa)
#    POS: noun.feminine.e
#    Definition: oath. क्षची 0 by X
#
# 34. आत (āta)
#    POS: postposition
#    Definition: in, inside. ० ल्या गाठीचे reserved
#
# 35. आदर्श (ādarśa)
#    POS: adjective
#    Definition: inv. ideal, model. ० ठेवणे to set as a model
#
# 36. आदेश (ādēśa)
#    POS: noun.masculine
#    Definition: order, instruction. ० देणे to order, instruct, direct
#
# 37. आनंद (ānanda)
#    POS: noun.masculine
#    Definition: happiness, joy. ० होणे to be happy
#
# 38. आपण (āpaṇa)
#    POS: pronoun
#    Definition: reflexive. ० होऊन of one's own accord
#
# 39. आपले (āpalē)
#    POS: possessive
#    Definition: of आपण
#
# 40. आभार (ābhāra)
#    POS: noun.masculine
#    Definition: pl. obligation. ० मानणे to thank
#
# 41. आभाळ (ābhāḷa)
#    POS: noun.neuter
#    Definition: overcast sky. ० येणे for the sky to become overcast. ० कोसळणे to meet with a calamity
#
# 42. आमचे (āmacē)
#    POS: possessive
#    Definition: of आम्ही
#
# 43. आमंत्रण (āmantraṇa)
#    POS: noun.neuter
#    Definition: invitation. ० देणे to invite
#
# 44. आमसूल (āmasūla)
#    POS: noun.neuter
#    Definition: dried rind of a fruit ( रातंबी ). Used for sourness in cooking
#
# 45. आमिष (āmiṣa)
#    POS: noun.neuter
#    Definition: bait, enticement. ० दाखवणे to offer enticement
#
# 46. आयते (āyatē)
#    POS: adjective
#    Definition: readymade. आयत्या वेळेला at the last minute
#
# 47. आराम (ārāma)
#    POS: noun.masculine
#    Definition: rest, relaxation. ० खुर्ची easy chair
#
# 48. आरोप (ārōpa)
#    POS: noun.masculine
#    Definition: accusation, charge. ० ठेवणे to accuse
#
# 49. आव (āva)
#    POS: noun.masculine
#    Definition: pretense. ० आणणे to make a pretense
#
# 50. आवड (āvaḍa)
#    POS: noun.feminine.i
#    Definition: liking. आवडीने with enjoyment
#
# 51. आवंढा (āvaṇḍhā)
#    POS: noun.masculine
#    Definition: gulp or mouthful of saliva. ० गिळणे to gulp, swallow
#
# 52. आवर (āvara)
#    POS: noun.masculine
#    Definition: control. ० घालणे to control
#
# 53. आवश्यक (āvaśyaka)
#    POS: None
#    Definition: See अवश्य (adj.)
#
# 54. आव्हान (āvhāna)
#    POS: noun.neuter
#    Definition: challenge. ० देणे to challenge
#
# 55. आशा (āśā)
#    POS: noun.feminine
#    Definition: hope. ० करणे to hope
#
# 56. आश्रय (āśraya)
#    POS: noun.masculine
#    Definition: asylum, refuge. ० देणे to give asylum
#
# 57. आस्वाद (āsvāda)
#    POS: noun.masculine
#    Definition: savor, relish. ० घेणे to savor, relish
#
# 58. आहार (āhāra)
#    POS: noun.masculine
#    Definition: fare. आहारी जाणे to be under the sway of
#
# 59. आहे (āhē)
#    POS: None
#    Definition: pres. of असणे
#
# 60. आळ (āḷa)
#    POS: noun.masculine
#    Definition: false accusation. ० येणे to be falsely accused
#
# 61. आळस (āḷasa)
#    POS: noun.masculine
#    Definition: laziness. ० येणे to feel lazy. ० देणे to stretch
#
# 62. आळोखेपिळोखे (āḷōkhēpiḷōkhē)
#    POS: noun.masculine
#    Definition: pl. stretching. ० देणे to stretch
#
# 63. आक्षेप (ākṣēpa)
#    POS: noun.masculine
#    Definition: objection. ० घेणे to object
#
# 64. इ (i)
#    POS: None
#    Definition: abbrev. of इत्यादी
#
# 65. इच्छा (icchā)
#    POS: noun.feminine
#    Definition: wish, desire. ० करणे to wish, desire. ० ठेवणे to have an unfulfilled desire
#
# 66. इंजिन (iñjina)
#    POS: None
#    Definition: See एंजिन
#
# 67. इशारा (iśārā)
#    POS: noun.masculine
#    Definition: warning. ० देणे to give a warning
#
# 68. इसवी (isavī)
#    POS: None
#    Definition: सन sana A. D
#
# 69. इस्त्री (istrī)
#    POS: noun.feminine
#    Definition: iron (for ironing clothes). ० करणे to iron
#
# 70. उकळी (ukaḷī)
#    POS: noun.feminine
#    Definition: boiling. ० येणे , फुटणे to come to a boil
#
# 71. उघडकीला (ughaḍakīlā)
#    POS: None
#    Definition: आणणे āṇaṇē to expose
#
# 72. उघडीप (ughaḍīpa)
#    POS: noun.feminine.i
#    Definition: clearing up (of the weather). ० पडणे for the weather to clear up
#
# 73. उचल (ucala)
#    POS: noun.feminine.i
#    Definition: lift. ० खाणे to take the first step
#
# 74. उच्च (ucca)
#    POS: adjective
#    Definition: inv. high. ० शिक्षण higher education
#
# 75. उच्चार (uccāra)
#    POS: noun.masculine
#    Definition: pronunciation. ० करणे to say, pronounce
#
# 76. उडी (uḍī)
#    POS: noun.feminine
#    Definition: jump, leap. ० मारणे , टाकणे , घेणे to jump
#
# 77. उताणे (utāṇē)
#    POS: adjective
#    Definition: lying on one's back. ० होणे to lie on one's back
#
# 78. उतू (utū)
#    POS: None
#    Definition: जाणे jāṇē to boil over
#
# 79. उत्तर (uttara)
#    POS: noun.neuter
#    Definition: answer, reply ० देणे to answer
#
# 80. उत्तीर्ण (uttīrṇa)
#    POS: None
#    Definition: होणे hōṇē to pass (an examination)
#
# 81. उत्तेजन (uttējana)
#    POS: noun.neuter
#    Definition: encouragement. ० देणे to encourage
#
# 82. उत्पन्न (utpanna)
#    POS: noun.neuter
#    Definition: earning. ० होणे to be created, be produced
#
# 83. उद्गार (udgāra)
#    POS: noun.masculine
#    Definition: utterance. ० काढणे to remark
#
# 84. उधारी (udhārī)
#    POS: noun.feminine
#    Definition: credit. ० ठेवणे , ० वर घेणे to buy on credit
#
# 85. उन्ह (unha)
#    POS: None
#    Definition: See ऊन
#
# 86. उपभोग (upabhōga)
#    POS: noun.masculine
#    Definition: experience, enjoyment. ० घेणे to experience, enjoy
#
# 87. उपवास (upavāsa)
#    POS: None
#    Definition: See उपास
#
# 88. उपस्थित (upasthita)
#    POS: adjective
#    Definition: inv. present. ० करणे to raise. ० होणे to be raised (as a question)
#
# 89. उपास (upāsa)
#    POS: noun.masculine
#    Definition: going without food, fast. ० करणे to fast. ० पडणे to have to go without food
#
# 90. उभे (ubhē)
#    POS: adjective
#    Definition: to confront. ० करणे ,
#
# 91. उभ्याउभ्या (ubhyāubhyā)
#    POS: adverb
#    Definition: just for a moment. ० येणे to pay a flying visit
#
# 92. उलट (ulaṭa)
#    POS: adjective
#    Definition: contrary, opposite. ० बोलणे to talk back. ० तपासणी cross examination
#
# 93. उवा (uvā)
#    POS: None
#    Definition: pl. of ऊ
#
# 94. उशीर (uśīra)
#    POS: noun.masculine
#    Definition: delay, lateness. ० करणे , होणे , लागणे to be late
#
# 95. उसण (usaṇa)
#    POS: noun.feminine.i
#    Definition: stitch (of pain). ० भरणे to have a stitch
#
# 96. उसासा (usāsā)
#    POS: noun.masculine
#    Definition: sigh, ० सोडणे , टाकणे to sigh
#
# 97. ऊन्ह (ūnha)
#    POS: None
#    Definition: See ऊन
#
# 98. एकजीव (ēkajīva)
#    POS: None
#    Definition: होणे hōṇē to become one with, become completely mixed in
#
# 99. एकरूप (ēkarūpa)
#    POS: None
#    Definition: होणे hōṇē to become one with
#
# 100. एकांतवास (ēkāntavāsa)
#    POS: noun.masculine
#    Definition: living in solitude. एकांतवासाची शिक्षा solitary confinement
#
# 101. एकुलते (ēkulatē)
#    POS: adjective
#    Definition: only. (Generally followed by एक )
#
# 102. एकेरी (ēkērī)
#    POS: adjective
#    Definition: singular, informal (address). ० वर येणे to be rude
#
# 103. एखादे (ēkhādē)
#    POS: None
#    Definition: See एकादे
#
# 104. एरव्ही (ēravhī)
#    POS: None
#    Definition: See एरवी
#
# 105. एस. (ēsa.)
#    POS: None
#    Definition: एस. ēsa. , सी sī S. S. C. (secondary school certificate, a school-leaving examination)
#
# 106. ऐन (aina)
#    POS: None
#    Definition: inv. adjunct intensifying the meaning of the following word, e. g., ० पावसाळ्यात at the height of the rainy season
#
# 107. ओढ (ōḍha)
#    POS: noun.feminine.i
#    Definition: longing. ० लागणे to long for
#
# 108. ओरडणे (ōraḍaṇē)
#    POS: verb.intransitive
#    Definition: to produce the cry characteristic of a particular animal or bird, e. g., बेडूक ओरडतो the frog croaks
#
# 109. ओळख (ōḷakha)
#    POS: noun.feminine.i
#    Definition: acquaintance. ० करून देणे to introduce. ० करून घेणे to get acquainted. ० पटणे to recognize
#
# 110. औषध (auṣadha)
#    POS: noun.neuter
#    Definition: chemical preparation. ० मारणे to spray a chemical (on a crop, in a house, etc. for pest control)
#
# 111. ऑर्डर (ôrḍara)
#    POS: noun.feminine.i
#    Definition: order. ० देणे to order, give an order
#
# 112. कच्चे (kaccē)
#    POS: adjective
#    Definition: crudely finished, unfinished. कच्चा माल raw materials. कच्चा रस्ता dirt road. ० बांधकाम construction with mud rather than concrete as mortar
#
# 113. कंटाळा (kaṇṭāḷā)
#    POS: noun.masculine
#    Definition: boredom. ० येणे to be bored
#
# 114. कटिंग (kaṭiṅga)
#    POS: noun.feminine
#    Definition: haircut. ० करणे to cut one's hair, have one's hair cut
#
# 115. कंठ (kaṇṭha)
#    POS: noun.masculine
#    Definition: throat. ० दाटणे to be choked with emotion. ० फुटणे to break into speech, become vocal
#
# 116. कडकडीत (kaḍakaḍīta)
#    POS: adjective
#    Definition: hard, severe rigorous. ० उपास rigorous fast. ० हरताळ total strike
#
# 117. कडी (kaḍī)
#    POS: None
#    Definition: करणे karaṇē to best
#
# 118. कडू (kaḍū)
#    POS: adjective
#    Definition: inv. bitter. ० तेल inedible oil used for lighting a lamp
#
# 119. कणव (kaṇava)
#    POS: noun.feminine.e
#    Definition: pity. ० येणे to feel pity
#
# 120. कधी (kadhī)
#    POS: adverb
#    Definition: when, ever. ० कधी sometimes. ० तरी sometime
#
# 121. कधीच (kadhīca)
#    POS: adverb
#    Definition: long back. ० नाही never
#
# 122. कपाळ (kapāḷa)
#    POS: noun.neuter
#    Definition: exasperated expletive, e. g., ० तुझं !
#
# 123. कबुली (kabulī)
#    POS: noun.feminine
#    Definition: confession. ० देणे to confess
#
# 124. कबूल (kabūla)
#    POS: adjective
#    Definition: inv. agreed, admitted. ० करणे to agree, admit
#
# 125. कमी (kamī)
#    POS: adverb
#    Definition: less, few, small in amount, insufficient. ० न करणे not to hesitate
#
# 126. कयास (kayāsa)
#    POS: noun.masculine
#    Definition: guess, estimate. ० करणे , बांधणे to guess, estimate
#
# 127. कर (kara)
#    POS: noun.masculine
#    Definition: tax. ० बसवणे to tax. ० भरणे , देणे to pay tax. m., f.,
#
# 128. कर (kara)
#    POS: suffix
#    Definition: of -- (place), e. g., नगर 0 `of Nagar', पुणे 0 `of Poona.' When a family moves to another town this designation often becomes a surname
#
# 129. कर (kara)
#    POS: suffix
#    Definition: e. g., विण 0 weaver
#
# 130. करकचणे (karakacaṇē)
#    POS: verb.transitive
#    Definition: to bind tightly. Generally used with a following verb, e. g., करकचून बांधणे
#
# 131. करण (karaṇa)
#    POS: suffix
#    Definition: meaning `making.' Of. Eng. -- ization, -- ification, e. g., औद्योगी industrialization, राष्ट्रीयी 0 nationalization
#
# 132. करिता (karitā)
#    POS: None
#    Definition: See करता
#
# 133. कर्ज (karja)
#    POS: noun.neuter
#    Definition: debt, loan. ० घेणे , काढणे to take a loan. ० देणे to give a loan
#
# 134. कर्तरी (kartarī)
#    POS: None
#    Definition: प्रयोग prayōga a sentence construction in which the verb agrees with the agent
#
# 135. कर्मणी (karmaṇī)
#    POS: None
#    Definition: प्रयोग prayōga a sentence construction in which the verb agrees with the object
#
# 136. कलंक (kalaṅka)
#    POS: noun.masculine
#    Definition: stigma, blot. ० लावणे to give a bad name, be a blot
#
# 137. कल्पना (kalpanā)
#    POS: noun.feminine
#    Definition: power of imagination. ० करणे to imagine
#
# 138. कविता (kavitā)
#    POS: noun.feminine
#    Definition: poetry, poem. ० करणे , लिहिणे to write poetry
#
# 139. कशा (kaśā)
#    POS: None
#    Definition: obl. form of कसे
#
# 140. कष्ट (kaṣṭa)
#    POS: None
#    Definition: m.pl. 1. hard work. ० करणे to work hard. 2. distress. ० होणे to be in distress
#
# 141. कसे (kasē)
#    POS: adverb
#    Definition: how. ० दिले ? How much does it cost ? (lit., How given ?)
#
# 142. कसोटी (kasōṭī)
#    POS: noun.feminine
#    Definition: test. ० घेणे to give a test. ० लावणे to apply a test. ० ला उतरणे to meet a test
#
# 143. कळ (kaḷa)
#    POS: noun.feminine.i
#    Definition: quarrelling. ० लावणे to incite a quarrel
#
# 144. कळस (kaḷasa)
#    POS: noun.masculine
#    Definition: pinnacle, height. ० होणे to reach a crisis
#
# 145. कळसूत्री (kaḷasūtrī)
#    POS: None
#    Definition: बाहुली bāhulī puppet
#
# 146. का (kā)
#    POS: None
#    Definition: कू kū , करणे karaṇē to hesitate
#
# 147. काकी (kākī)
#    POS: None
#    Definition: See काकू
#
# 148. काचा (kācā)
#    POS: noun.masculine
#    Definition: tuck. ० मारणे . to tuck up
#
# 149. काटा (kāṭā)
#    POS: noun.masculine
#    Definition: goosepimples. अंगावर ० उभा राहणे to get goosepimples
#
# 150. काढणे (kāḍhaṇē)
#    POS: verb.transitive
#    Definition: to pull, draw out, take out. काढून घेणे to take away
#
# 151. कात (kāta)
#    POS: noun.feminine.i
#    Definition: skin (esp. of a snake). ० टाकणे to shed a skin
#
# 152. कात (kāta)
#    POS: noun.masculine
#    Definition: catechu (an ingredient of पान )
#
# 153. कान (kāna)
#    POS: noun.masculine
#    Definition: ear. As in Eng. this is also used to refer to the ear of a cup. ० देणे to listen. कानावर पडणे to hear
#
# 154. कानाडोळा (kānāḍōḷā)
#    POS: None
#    Definition: करणे karaṇē to wink at, overlook
#
# 155. काबीज (kābīja)
#    POS: None
#    Definition: करणे karaṇē to seize, take over
#
# 156. काबूत (kābūta)
#    POS: None
#    Definition: येणे yēṇē to come within the control of
#
# 157. काम (kāma)
#    POS: noun.neuter
#    Definition: work. कामाला or कामावर जाणे to go to work
#
# 158. कार (kāra)
#    POS: suffix
#    Definition: agentive suff., e.g., कला 0 artist
#
# 159. कारणीभूत (kāraṇībhūta)
#    POS: adjective
#    Definition: inv. causative. ० होणे to be the cause of
#
# 160. कारवाई (kāravāī)
#    POS: noun.feminine
#    Definition: scheme. ० करणे to take action
#
# 161. कार्य (kārya)
#    POS: noun.neuter
#    Definition: task, work. Usually refers to work of greater significance than does काम
#
# 162. काल (kāla)
#    POS: adverb
#    Definition: yesterday. See also काळ
#
# 163. काळजी (kāḷajī)
#    POS: noun.feminine
#    Definition: anxiety, worry. care. ० करणे , वाटणे to worry
#
# 164. काळजी (kāḷajī)
#    POS: noun.feminine
#    Definition: solicitude. ० घेणे to take pains, care for
#
# 165. काळिमा (kāḷimā)
#    POS: noun.masculine
#    Definition: stain, blot. ० लावणे to give a bad name, be a blot, blacken
#
# 166. किटणे (kiṭaṇē)
#    POS: verb.intransitive
#    Definition: to be fed up with. आवाजाने कान 0 to be fed up with a noise
#
# 167. कितवे (kitavē)
#    POS: adjective
#    Definition: which (regarding position in a series). कितवी which grade
#
# 168. किती (kitī)
#    POS: None
#    Definition: inv. how much, how many. ० वाजता at what time
#
# 169. की (kī)
#    POS: conjunction
#    Definition: or. Emphatic particle, e. g., या की do come
#
# 170. कीड (kīḍa)
#    POS: noun.feminine.i
#    Definition: insect, worm, maggot. ० लागणे , पडणे to be attacked by insects
#
# 171. कीव (kīva)
#    POS: noun.feminine.e
#    Definition: pity. ० येणे , करणे to pity
#
# 172. कीस (kīsa)
#    POS: noun.masculine
#    Definition: gratings, scrapings. ० काढणे to make fine distinctions
#
# 173. कु (ku)
#    POS: None
#    Definition: abbrev. of कुमार or कुमारी
#
# 174. कुणकुण (kuṇakuṇa)
#    POS: noun.feminine.i
#    Definition: whisper, rumor. ० लागणे to hear a rumor
#
# 175. कुणी (kuṇī)
#    POS: pronoun
#    Definition: instr. of कोण
#
# 176. कुभांड (kubhāṇḍa)
#    POS: noun.neuter
#    Definition: false accusation. ० रचणे to accuse falsely
#
# 177. कुरापत (kurāpata)
#    POS: None
#    Definition: काढणे kāḍhaṇē to provoke
#
# 178. कुलूप (kulūpa)
#    POS: noun.neuter
#    Definition: lock. ० लावणे to lock
#
# 179. कूस (kūsa)
#    POS: noun.feminine.i
#    Definition: side of the body. क्षच्या कुशीत in X's arms
#
# 180. कृती (kṛtī)
#    POS: noun.feminine
#    Definition: action. ० करणे to take action
#
# 181. कृत्य (kṛtya)
#    POS: noun.neuter
#    Definition: action. ० करणे to perform an action
#
# 182. कृपा (kṛpā)
#    POS: noun.feminine
#    Definition: favor, kindness. क्षच्या कृपेने thanks to X. ० करणे to be kind. do a favor
#
# 183. केर (kēra)
#    POS: noun.masculine
#    Definition: rubbish. ० काढणे to sweep
#
# 184. केरवारा (kēravārā)
#    POS: None
#    Definition: करणे karaṇē to sweep, clean
#
# 185. कैवार (kaivāra)
#    POS: None
#    Definition: घेणे ghēṇē to align oneself with one side in a dispute
#
# 186. कोठडी (kōṭhaḍī)
#    POS: noun.feminine
#    Definition: storeroom. अंधार dungeon
#
# 187. कोठे (kōṭhē)
#    POS: None
#    Definition: See कुठे
#
# 188. कोंडणे (kōṇḍaṇē)
#    POS: verb.transitive
#    Definition: to shut in, confine. श्वास 0 to hold one's breath, stifle
#
# 189. कोणी (kōṇī)
#    POS: None
#    Definition: See कुणी
#
# 190. कोलांटी (kōlāṇṭī)
#    POS: noun.feminine
#    Definition: somersault. ० मारणे to somersault
#
# 191. खटका (khaṭakā)
#    POS: noun.masculine
#    Definition: spat. ० उडणे for a spat to occur
#
# 192. खंड (khaṇḍa)
#    POS: noun.masculine
#    Definition: tax, land rent. खंडाने घेणे to take on lease (as land)
#
# 193. खडबडून (khaḍabaḍūna)
#    POS: None
#    Definition: जागे jāgē , होणे hōṇē to startle awake
#
# 194. खबर (khabara)
#    POS: noun.feminine.i
#    Definition: news. ० देणे to inform
#
# 195. खबरदारी (khabaradārī)
#    POS: noun.feminine
#    Definition: care ० घेणे to take care
#
# 196. खरे (kharē)
#    POS: adverb
#    Definition: var. really, truly. ० बोलणे to tell the truth
#
# 197. खरेखुरे (kharēkhurē)
#    POS: adjective
#    Definition: redupl. of खरे
#
# 198. खर्च (kharca)
#    POS: noun.masculine
#    Definition: expense, cost. ० करणे to spend. ० होणे to cost, be spent
#
# 199. खस्ता (khastā)
#    POS: None
#    Definition: f.pl. pains, trouble. ० खाणे to take pains
#
# 200. खाऊ (khāū)
#    POS: noun.masculine
#    Definition: snacks, `eats'. ० घालणे to feed
#
# 201. खाक (khāka)
#    POS: None
#    Definition: होणे hōṇē to be burned to ashes
#
# 202. खाज (khāja)
#    POS: noun.feminine.e
#    Definition: itch. ० सुटणे to itch
#
# 203. खाडा (khāḍā)
#    POS: noun.masculine
#    Definition: break (in an activity). कामात 0 होणे for a break to occur in one's work
#
# 204. खाणाखुणा (khāṇākhuṇā)
#    POS: None
#    Definition: redupl. of खूण
#
# 205. खाणे (khāṇē)
#    POS: verb.transitive
#    Definition: (irreg.) to eat. हवा 0 to get some air. पैसे 0 to embezzle money or take bribes. खायला घालणे to feed, fertilize
#
# 206. खात्री (khātrī)
#    POS: noun.feminine
#    Definition: confidence, trust. ० पटणे to be convinced
#
# 207. खांदा (khāndā)
#    POS: noun.masculine
#    Definition: shoulder. ० देणे to help (esp. in carrying a dead body)
#
# 208. खितपत (khitapata)
#    POS: None
#    Definition: पडणे paḍaṇē to languish
#
# 209. खिरापत (khirāpata)
#    POS: noun.feminine.i
#    Definition: sweets distributed after the worship of a god. ० वाटणे to distribute sweets
#
# 210. खुबी (khubī)
#    POS: noun.feminine
#    Definition: trick. ० ने skillfully
#
# 211. खुलासा (khulāsā)
#    POS: noun.masculine
#    Definition: clarification. ० देणे , करणे to clarify, explain
#
# 212. खुषी (khuṣī)
#    POS: noun.feminine
#    Definition: pleasure. खुषीत असणे to be pleased
#
# 213. खेटून (khēṭūna)
#    POS: None
#    Definition: बसणे basaṇē to press against
#
# 214. खेडीपाडी (khēḍīpāḍī)
#    POS: None
#    Definition: redupl. of खेडे
#
# 215. खेप (khēpa)
#    POS: noun.feminine.e
#    Definition: trip, turn. ० घालणे to make a trip
#
# 216. खोकरणे (khōkaraṇē)
#    POS: None
#    Definition: redupl. of खाकरणे
#
# 217. खोटे (khōṭē)
#    POS: adjective
#    Definition: false, imitation. ० बोलणे . to lie
#
# 218. खोडी (khōḍī)
#    POS: None
#    Definition: करणे karaṇē to do mischief
#
# 219. गचांडी (gacāṇḍī)
#    POS: noun.feminine
#    Definition: scruff of the neck. ० देणे to give a push by the scruff of the neck
#
# 220. गटगंळी (gaṭagaṃḷī)
#    POS: None
#    Definition: खाणे khāṇē to sink and come up while drowning
#
# 221. गट्ट (gaṭṭa)
#    POS: None
#    Definition: करणे karaṇē to eat up
#
# 222. गडप (gaḍapa)
#    POS: None
#    Definition: होणे hōṇē to disappear
#
# 223. गड्या (gaḍyā)
#    POS: None
#    Definition: voc. sg. of गडी
#
# 224. गणपती (gaṇapatī)
#    POS: None
#    Definition: See गणेश
#
# 225. गंध (gandha)
#    POS: noun.masculine
#    Definition: smell. ० नसणे not to have even a trace
#
# 226. गनिमी (ganimī)
#    POS: None
#    Definition: कावा kāvā guerilla warfare
#
# 227. गप्पा (gappā)
#    POS: noun.feminine
#    Definition: pl. chatting. ० मारणे , छाटणे , झोडणे to chat
#
# 228. गंमत (gammata)
#    POS: noun.feminine.i
#    Definition: fun. ० वाटणे to enjoy, find interesting. ० करणे to do something in a light vein or as a joke
#
# 229. गम्मत (gammata)
#    POS: None
#    Definition: See गंमत
#
# 230. गय (gaya)
#    POS: None
#    Definition: करणे karaṇē to condone
#
# 231. गराडा (garāḍā)
#    POS: noun.masculine
#    Definition: encirclement. ० घालणे to surround
#
# 232. गवती (gavatī)
#    POS: None
#    Definition: चहा cahā lemon grass
#
# 233. गव्हा (gavhā)
#    POS: None
#    Definition: obl. of गहू
#
# 234. गस्त (gasta)
#    POS: noun.feminine.i
#    Definition: patrol. ० घालणे to patrol
#
# 235. गहाण (gahāṇa)
#    POS: adjective
#    Definition: inv. pawned. ० टाकणे to pawn
#
# 236. गळ (gaḷa)
#    POS: noun.masculine
#    Definition: fish-hook. ० घालणे to press, importune
#
# 237. गळणे (gaḷaṇē)
#    POS: verb.intransitive
#    Definition: to drop off. गळून जाणे to become exhausted
#
# 238. गळती (gaḷatī)
#    POS: noun.feminine
#    Definition: leak. ० लागणे to leak
#
# 239. गळा (gaḷā)
#    POS: noun.masculine
#    Definition: voice. ० काढणे to wail
#
# 240. गाठ (gāṭha)
#    POS: noun.feminine.i
#    Definition: knot. ० बांधणे to tie a knot, make a connection
#
# 241. गाठ (gāṭha)
#    POS: noun.feminine.i
#    Definition: meeting. ० पडणे to meet. ० असणे to have to deal with
#
# 242. गायले (gāyalē)
#    POS: None
#    Definition: perf. of गाणे
#
# 243. गार (gāra)
#    POS: suffix
#    Definition: agentive suff., e. g., काम 0 worker. Intensifying adjunct, e.g., थंड 0 very cold, हिरवे 0 bright green, deep green
#
# 244. गालगुच्चा (gālaguccā)
#    POS: noun.masculine
#    Definition: pinch on the cheek. ० घेणे to pinch a cheek
#
# 245. गाव (gāva)
#    POS: noun.neuter
#    Definition: town. गावात downtown. गावाला जाणे to go out of town
#
# 246. गावी (gāvī)
#    POS: None
#    Definition: नसणे nasaṇē not to be aware of
#
# 247. गाशा (gāśā)
#    POS: None
#    Definition: गुंडाळणे guṇḍāḷaṇē to pick up and leave
#
# 248. गाळण (gāḷaṇa)
#    POS: None
#    Definition: उडणे uḍaṇē to be extremely frightened
#
# 249. गीर (gīra)
#    POS: suffix
#    Definition: e. g., कारा 0 skilled worker
#
# 250. गुंगारा (guṅgārā)
#    POS: None
#    Definition: देणे dēṇē to give the slip
#
# 251. गुडघा (guḍaghā)
#    POS: noun.masculine
#    Definition: knee. गुडघे टेकणे to assume the pose of a supplicant
#
# 252. गुढी (guḍhī)
#    POS: noun.feminine
#    Definition: decorated pole erected on top of or in front of the house to celebrate गुढीपाडवा
#
# 253. गुढीपाडवा (guḍhīpāḍavā)
#    POS: noun.masculine
#    Definition: new year's day (the first day of चैत्र )
#
# 254. गुण (guṇa)
#    POS: noun.masculine
#    Definition: curative effect. औषधाचा ० येणे for a medicine to be effective
#
# 255. गुंतागुंत (guntāgunta)
#    POS: noun.feminine.i
#    Definition: complication, complexity. गुंतागुंतीचे complicated
#
# 256. गुवा (guvā)
#    POS: None
#    Definition: obl. of गू
#
# 257. गुळणी (guḷaṇī)
#    POS: noun.feminine
#    Definition: mouthful of liquid. गुळण्या करणे to gargle
#
# 258. गुळंबा (guḷambā)
#    POS: noun.masculine
#    Definition: mangoes preserved in गूळ
#
# 259. गृहीत (gṛhīta)
#    POS: adjective
#    Definition: inv. given, taken for granted. ० धरणे to take for granted
#
# 260. गोता (gōtā)
#    POS: noun.masculine
#    Definition: dip, plunge. ० खाणे to take a plunge
#
# 261. गोंधळ (gōndhaḷa)
#    POS: noun.masculine
#    Definition: noise. ० करणे , घालणे to make a noise
#
# 262. गोंधळ (gōndhaḷa)
#    POS: noun.masculine
#    Definition: a folk-art form, consisting of narrative presented through songs accompanied by instrumental music. and pantomime. ० घालणे to perform a गोंधळ
#
# 263. गोळा (gōḷā)
#    POS: noun.masculine
#    Definition: round object, ball, mass. पोटचा 0 child. ० करणे to collect, assemble. ० होणे to gather around
#
# 264. गौळण (gauḷaṇa)
#    POS: None
#    Definition: See गवळण
#
# 265. ग्राम (grāma)
#    POS: prefix
#    Definition: village. ० सेवक village level worker in the panchayat samiti
#
# 266. ग्लानी (glānī)
#    POS: noun.feminine
#    Definition: fatigue, lack of energy. ० येणे to be fatigued, feel listless
#
# 267. घटस्फोट (ghaṭasphōṭa)
#    POS: noun.masculine
#    Definition: divorce. ० घेणे to get a divorce. ० देणे to give a divorce
#
# 268. घडी (ghaḍī)
#    POS: noun.feminine
#    Definition: fold. घडीचे new (with the original folds unopened)
#
# 269. घर (ghara)
#    POS: noun.neuter
#    Definition: house. ० डोक्यावर घेणे to raise the roof
#
# 270. घरोघर (gharōghara)
#    POS: None
#    Definition: घरोघरी gharōgharī in every house
#
# 271. घाट (ghāṭa)
#    POS: noun.masculine
#    Definition: design, plan. ० घालणे to plan
#
# 272. घाण (ghāṇa)
#    POS: adjective
#    Definition: inv. dirty. ० येणे to stink
#
# 273. घाणा (ghāṇā)
#    POS: noun.masculine
#    Definition: oil mill. ० काढणे to crush for oil
#
# 274. घातले (ghātalē)
#    POS: None
#    Definition: perf. of घालणे
#
# 275. घाम (ghāma)
#    POS: noun.masculine
#    Definition: sweat. ० येणे to sweat. ० सुटणे , फुटणे to be frightened
#
# 276. घामोळे (ghāmōḷē)
#    POS: noun.neuter
#    Definition: prickly heat. ० येणे , उठणे to get prickly heat
#
# 277. घायपात (ghāyapāta)
#    POS: noun.feminine.i
#    Definition: sisal. See केकताड
#
# 278. घाला (ghālā)
#    POS: noun.masculine
#    Definition: attack. ० घालणे to attack
#
# 279. घुटका (ghuṭakā)
#    POS: None
#    Definition: See घोट
#
# 280. घेतले (ghētalē)
#    POS: None
#    Definition: perf. of घेणे
#
# 281. चकाट्य (cakāṭya)
#    POS: None
#    Definition: f.pl. idle talk. ० पॢटणे to chat idly
#
# 282. चकार (cakāra)
#    POS: None
#    Definition: शब्द śabda a single word or syllable. Used only with negative
#
# 283. चक्कर (cakkara)
#    POS: noun.feminine.e
#    Definition: going in circles. ० मारणे to take a round, to go round
#
# 284. चक्कर (cakkara)
#    POS: noun.feminine.e
#    Definition: dizziness. ० येणे to become dizzy
#
# 285. चंग (caṅga)
#    POS: None
#    Definition: (m.) बांधणे to make up one's mind (to do something)
#
# 286. चंगळ (caṅgaḷa)
#    POS: noun.feminine.i
#    Definition: abundance, profusion. ० करणे to enjoy an abundance
#
# 287. चटक (caṭaka)
#    POS: None
#    Definition: (f.) लागणे to develop a taste for something
#
# 288. चट्टामट्टा (caṭṭāmaṭṭā)
#    POS: None
#    Definition: (m.) करणे to clean up, eat up
#
# 289. चतकोर (catakōra)
#    POS: adjective
#    Definition: inv. one fourth of a round object like a भाकरी
#
# 290. चपाती (capātī)
#    POS: noun.feminine
#    Definition: wheat pancake used as bread. See पोळी
#
# 291. चराऊ (carāū)
#    POS: None
#    Definition: रान rāna grazing land
#
# 292. चरितार्थ (caritārtha)
#    POS: noun.masculine
#    Definition: living, livelihood. ० चालवणे to earn a living
#
# 293. चलबिचल (calabicala)
#    POS: noun.feminine.i
#    Definition: unsettledness. मनाची 0 to be disturbed
#
# 294. चव्हाटा (cavhāṭā)
#    POS: noun.masculine
#    Definition: meeting point of four roads. चव्हाट्यावर आणणे to make public
#
# 295. चळ (caḷa)
#    POS: None
#    Definition: (m.) लागणे to be off one's rocker
#
# 296. चाटणे (cāṭaṇē)
#    POS: verb.transitive
#    Definition: to lick. चाटून टाकणे to eat up, finish off
#
# 297. चालणे (cālaṇē)
#    POS: verb.intransitive
#    Definition: to be acceptable. चालेल OK
#
# 298. चालवणे (cālavaṇē)
#    POS: verb.transitive
#    Definition: to do, e g., तू काय चालवलं आहेस ? What are you doing ?
#
# 299. चालून (cālūna)
#    POS: None
#    Definition: येणे yēṇē 1. to come of one's own accord. 2. to attack
#
# 300. चावा (cāvā)
#    POS: noun.masculine
#    Definition: bite. ० घेणे to bite
#
# 301. चाहूल (cāhūla)
#    POS: None
#    Definition: f (i) sound indicating someone's approach. ० लागणे to become aware of someone's approach
#
# 302. चि. (ci.)
#    POS: None
#    Definition: abbrev. of चिरंजीव
#
# 303. चिपटे (cipaṭē)
#    POS: noun.neuter
#    Definition: measure equal to one-quarter शेर
#
# 304. चिमटा (cimaṭā)
#    POS: noun.masculine
#    Definition: pinch. ० घेणे to pinch
#
# 305. चीक (cīka)
#    POS: noun.masculine
#    Definition: sap. चिकात असणे to be in the milky stage (said of grain)
#
# 306. चीड (cīḍa)
#    POS: noun.feminine.i
#    Definition: anger. ० येणे to get mad
#
# 307. चीर (cīra)
#    POS: noun.feminine.e
#    Definition: crack, slit. ० पडणे to crack
#
# 308. चुकणे (cukaṇē)
#    POS: verb.intransitive
#    Definition: to err, make a mistake. न चुकता without fail
#
# 309. चुकणे (cukaṇē)
#    POS: verb.intransitive
#    Definition: As the second member of a cpd. verb ० has the sense of finality, e. g., मी बोलून चुकलो , I went and said it
#
# 310. चुटपुट (cuṭapuṭa)
#    POS: noun.feminine.i
#    Definition: regret. ० लागणे to regret
#
# 311. चुंबन (cumbana)
#    POS: noun.neuter
#    Definition: kiss. ० घेणे to kiss
#
# 312. चुलत (culata)
#    POS: adjective
#    Definition: inv. paternal uncle's. Used in cpd. kinship terms, e.g., ० भाऊ father's brother's son
#
# 313. चुळबुळ (cuḷabuḷa)
#    POS: noun.feminine.i
#    Definition: movement. ० करणे to move restlessly, fidget
#
# 314. चूड (cūḍa)
#    POS: noun.feminine.i
#    Definition: torch. ० लागणे to be put to the torch
#
# 315. चूप (cūpa)
#    POS: adjective
#    Definition: inv. quiet, silent. ० राहणे to keep quiet
#
# 316. चूळ (cūḷa)
#    POS: noun.feminine.e
#    Definition: the palm of the hand cupped to contain a liquid. ० भरणे to rinse one's mouth
#
# 317. चेंदामेंदा (cēndāmēndā)
#    POS: None
#    Definition: होणे hōṇē to be crushed, be smashed
#
# 318. चेष्टा (cēṣṭā)
#    POS: noun.feminine
#    Definition: mischief. ० करणे to make fun of
#
# 319. चेहरा (cēharā)
#    POS: noun.masculine
#    Definition: face, expression. ० उतरणे for one's face to fall
#
# 320. चैन (caina)
#    POS: noun.feminine.i
#    Definition: enjoyment. ० करणे to enjoy (oneself)
#
# 321. चोचले (cōcalē)
#    POS: None
#    Definition: पुरवणे puravaṇē to pander to (someone's) fancies
#
# 322. चोरटे (cōraṭē)
#    POS: adjective
#    Definition: clandestine, illegal, contraband. चोरट्यासारखे वाटणे to feel guilty
#
# 323. चोरी (cōrī)
#    POS: noun.feminine
#    Definition: concealing, withholding. V- ण्याची ० होणे not to feel free to V
#
# 324. चोरून (cōrūna)
#    POS: adverb
#    Definition: covertly. ० ऐकणे to eavesdrop
#
# 325. चोहीकडे (cōhīkaḍē)
#    POS: None
#    Definition: See चहुकडे
#
# 326. चौकशी (caukaśī)
#    POS: noun.feminine
#    Definition: inquiry. ० करणे to inquire
#
# 327. छाप (chāpa)
#    POS: noun.feminine.e
#    Definition: impression. ० पाडणे to impress
#
# 328. छापा (chāpā)
#    POS: noun.masculine
#    Definition: raid, attack. ० घालणे to make a raid, attack
#
# 329. छे (chē)
#    POS: interjection
#    Definition: no. ० छे an expression of denial or sympathy
#
# 330. जख्ख (jakhkha)
#    POS: None
#    Definition: intensifying adjunct commonly used with म्हातारे
#
# 331. जड (jaḍa)
#    POS: adjective
#    Definition: difficult. ० जाणे to go hard
#
# 332. जणी (jaṇī)
#    POS: noun.feminine
#    Definition: pl. of जण
#
# 333. जणे (jaṇē)
#    POS: noun.neuter
#    Definition: pl. of जण
#
# 334. जपजाप्य (japajāpya)
#    POS: noun.neuter
#    Definition: जप and such practices
#
# 335. जप्ती (japtī)
#    POS: noun.feminine
#    Definition: attachment (of property in payment of outstanding debts). ० येणे to have (one's property) attached
#
# 336. जम (jama)
#    POS: None
#    Definition: (m.) बसणे to become established
#
# 337. जमवणे (jamavaṇē)
#    POS: verb.transitive
#    Definition: to match, harmonize. जमवून घेणे to adjust, get along
#
# 338. जय (jaya)
#    POS: noun.masculine
#    Definition: victory. ० क्ष victory to X
#
# 339. जवळ (javaḷa)
#    POS: postposition
#    Definition: near, to, with. ० असणे to have, be near
#
# 340. जशास (jaśāsa)
#    POS: None
#    Definition: तसे tasē tit for tat
#
# 341. जागजागी (jāgajāgī)
#    POS: None
#    Definition: redupl. loc. of जागा . here and there, in various places
#
# 342. जाणे (jāṇē)
#    POS: None
#    Definition: habitual of जाणणे
#
# 343. जातपात (jātapāta)
#    POS: None
#    Definition: redupl. of जात . caste and family background
#
# 344. जांभई (jāmbhaī)
#    POS: noun.feminine
#    Definition: yawn. देणे to yawn
#
# 345. जामीन (jāmīna)
#    POS: noun.masculine
#    Definition: security, surety. राहणे to stand security, stand guarantee
#
# 346. जिकडे (jikaḍē)
#    POS: adverb
#    Definition: where, whither. ० तिकडे everywhere
#
# 347. जिव्हारी (jivhārī)
#    POS: None
#    Definition: लागणे lāgaṇē to be hurt or cut to the quick
#
# 348. जीव (jīva)
#    POS: noun.masculine
#    Definition: energy. ० देणे to commit suicide. ० भांड्यात पडणे to be relieved
#
# 349. जुगार (jugāra)
#    POS: noun.masculine
#    Definition: gambling. खेळणे to gamble
#
# 350. जेथ (jētha)
#    POS: None
#    Definition: See जिथे
#
# 351. जेरी (jērī)
#    POS: noun.feminine
#    Definition: defeat, harassment. ०सयेणे to be harassed, be brought to the end of one's tether
#
# 352. जो (jō)
#    POS: None
#    Definition: जो jō go to sleep. This is the traditional refrain of a lullaby
#
# 353. जोडणे (jōḍaṇē)
#    POS: verb.transitive
#    Definition: to join together, put together. संबंध to establish a relationship
#
# 354. ज्वालामुखी (jvālāmukhī)
#    POS: adjective
#    Definition: inv. volcanic. पर्वत volcano
#
# 355. झटका (jhaṭakā)
#    POS: noun.masculine
#    Definition: shock. ० बसणे to receive a shock
#
# 356. झळ (jhaḷa)
#    POS: noun.feminine.i
#    Definition: radiated heat. ० लागणे to feel heat, suffer from
#
# 357. झाले (jhālē)
#    POS: None
#    Definition: perf. of ० . च तर further, what's more
#
# 358. झुकांडी (jhukāṇḍī)
#    POS: None
#    Definition: (f.) देणे to give the slip
#
# 359. झूट (jhūṭa)
#    POS: adjective
#    Definition: inv. false. ० धेणे to lie
#
# 360. झेप (jhēpa)
#    POS: noun.feminine.e
#    Definition: lunge. ० धेणे to lunge
#
# 361. झोका (jhōkā)
#    POS: noun.masculine
#    Definition: swinging movement, oscillation. ० धेणे to swing
#
# 362. झोप (jhōpa)
#    POS: None
#    Definition: f.(e.) sleep. ० लागणे to fall asleep
#
# 363. झोळी (jhōḷī)
#    POS: noun.feminine
#    Definition: begging cloth. ० धेणे to take up begging
#
# 364. टक (ṭaka)
#    POS: noun.masculine
#    Definition: unblinking gaze. ० लावणे to stare
#
# 365. टक्कल (ṭakkala)
#    POS: noun.neuter
#    Definition: bald head. पडणे to go bald
#
# 366. टर (ṭara)
#    POS: noun.feminine
#    Definition: derision, ridicule. ० उडवणे to deride, ridicule
#
# 367. टाकणे (ṭākaṇē)
#    POS: verb.transitive
#    Definition: As the second member of a cpd. verb ० has the sense of finality, e. g., संपवून to finish off
#
# 368. टाकी (ṭākī)
#    POS: noun.feminine
#    Definition: ० लावणे to roughen a stone surface by chipping
#
# 369. टाहो (ṭāhō)
#    POS: noun.masculine
#    Definition: wail. ० फडणे to wail
#
# 370. टाळी (ṭāḷī)
#    POS: noun.feminine
#    Definition: clapping. ० वाजवणे to clap
#
# 371. टिकाव (ṭikāva)
#    POS: noun.masculine
#    Definition: lasting. ० धरणे to last, endure
#
# 372. टिमकी (ṭimakī)
#    POS: noun.feminine
#    Definition: small drum. ० वाजवाणे to tomtom
#
# 373. टीका (ṭīkā)
#    POS: noun.feminine
#    Definition: criticism. ० करणे to criticize
#
# 374. टोचणी (ṭōcaṇī)
#    POS: noun.feminine
#    Definition: pricking. ० लागणे to be bothered, feel guilty
#
# 375. टोमणी (ṭōmaṇī)
#    POS: noun.masculine
#    Definition: taunt. ० मारणे to taunt
#
# 376. टोला (ṭōlā)
#    POS: noun.masculine
#    Definition: striking of a bell, clock, etc. ० पडणे for a bell or clock to strike
#
# 377. ठणका (ṭhaṇakā)
#    POS: noun.masculine
#    Definition: throbbing, hurting. ० लागणे to throb, hurt
#
# 378. ठपका (ṭhapakā)
#    POS: noun.masculine
#    Definition: imputation of crime. ० ठवणे to impute a crime
#
# 379. ठाऊक (ṭhāūka)
#    POS: adjective
#    Definition: inv. known. ० असणे to know
#
# 380. ठाण (ṭhāṇa)
#    POS: None
#    Definition: मांडवे māṇḍavē to park, settle oneself firmly
#
# 381. ठाव (ṭhāva)
#    POS: noun.masculine
#    Definition: bottom. ० धेणे to get to the bottom of
#
# 382. ठिकठिकाणी (ṭhikaṭhikāṇī)
#    POS: None
#    Definition: redupl. loc. of ठिकाण . here and there
#
# 383. ठिक्कर (ṭhikkara)
#    POS: None
#    Definition: intensifying adjunct used with काळे
#
# 384. ठेच (ṭhēca)
#    POS: noun.feminine.e
#    Definition: striking of foot against stone, ground, etc. ० लागणे to stub one's toe
#
# 385. ठेवणे (ṭhēvaṇē)
#    POS: verb.transitive
#    Definition: to put, place. ठेवून धेणे to keep, retain. ठेवून देणे to set aside
#
# 386. ठोकणे (ṭhōkaṇē)
#    POS: verb.transitive
#    Definition: to beat up. ठोकून देणे (C) to say off the top of one's head
#
# 387. डल्ला (ḍallā)
#    POS: None
#    Definition: (m.) मारणे to loot
#
# 388. डोई (ḍōī)
#    POS: noun.feminine
#    Definition: head. दर 0 per capita
#
# 389. डोके (ḍōkē)
#    POS: noun.neuter
#    Definition: head. डोक्यात राख घालणे to become unnecessarily angry
#
# 390. डोलणे (ḍōlaṇē)
#    POS: None
#    Definition: See डुलणे
#
# 391. डोळा (ḍōḷā)
#    POS: noun.masculine
#    Definition: eye, ० लागणे to sleep. ० घालणे to wink
#
# 392. ढुंकून (ḍhuṅkūna)
#    POS: None
#    Definition: न na , पहाणे pahāṇē not even to spare a glance
#
# 393. ढुस्स (ḍhussa)
#    POS: None
#    Definition: intensifying adjunct used with काळे
#
# 394. ढेप (ḍhēpa)
#    POS: None
#    Definition: f.(e). a mould of गूळ
#
# 395. तग (taga)
#    POS: noun.masculine
#    Definition: lasting, holding out. ० धरणे to last, hold out
#
# 396. तड (taḍa)
#    POS: noun.feminine.i
#    Definition: end. तडीस नेणे to finish
#
# 397. तपकीर (tapakīra)
#    POS: noun.feminine.i
#    Definition: snuff. ० ओढणे to take snuff
#
# 398. तमासगीर (tamāsagīra)
#    POS: noun.masculine
#    Definition: player in तमाशा
#
# 399. तहान (tahāna)
#    POS: noun.feminine.e
#    Definition: thirst. ० लागणे to be thirsty
#
# 400. ताडी (tāḍī)
#    POS: noun.feminine
#    Definition: spirit extracted from the ताड tree
#
# 401. ताप (tāpa)
#    POS: noun.masculine
#    Definition: fever, heat. ० येणे to have fever
#
# 402. तांबडे (tāmbaḍē)
#    POS: adjective
#    Definition: red. ० फुटणे to dawn
#
# 403. ताबूत (tābūta)
#    POS: noun.masculine
#    Definition: a float representing a tomb taken out in procession for the Muslim festival of मोहरम
#
# 404. तार (tāra)
#    POS: noun.feminine.e
#    Definition: telegram. ० करणे to telegraph
#
# 405. तारा (tārā)
#    POS: noun.masculine
#    Definition: star. तारे तोडणे to talk foolishly
#
# 406. ताव (tāva)
#    POS: None
#    Definition: मारणे māraṇē to eat heartily
#
# 407. ताशेरा (tāśērā)
#    POS: noun.masculine
#    Definition: verbal attack. ० झाडणे to criticize strongly
#
# 408. ताळ (tāḷa)
#    POS: None
#    Definition: सोडणे sōḍaṇē to lose control, lose sense of propriety
#
# 409. तिकीट (tikīṭa)
#    POS: noun.neuter
#    Definition: ticket. ० काढणे to buy a ticket
#
# 410. तिळगूळ (tiḷagūḷa)
#    POS: noun.masculine
#    Definition: a mixture of sesamum seed and jaggery distributed at the festival of संक्रांत
#
# 411. तिळपापड (tiḷapāpaḍa)
#    POS: None
#    Definition: होणे hōṇē to get mad
#
# 412. तीथ (tītha)
#    POS: None
#    Definition: See तिथी
#
# 413. तुच्छ (tuccha)
#    POS: adjective
#    Definition: inv. contemptible. ० लेखणे to treat with contempt
#
# 414. तुझे (tujhē)
#    POS: possessive
#    Definition: of तू
#
# 415. तुणतुणे (tuṇatuṇē)
#    POS: noun.neuter
#    Definition: one-stringed musical instrument. लावणे , वाजवणे to harp on
#
# 416. तुंबडी (tumbaḍī)
#    POS: noun.feminine
#    Definition: begging bowl. ० भरणे to fill one's own pockets, see to one's own profit
#
# 417. तुमचे (tumacē)
#    POS: possessive
#    Definition: of तुम्ही
#
# 418. तुरी (turī)
#    POS: None
#    Definition: देणे dēṇē to give the slip
#
# 419. तुरुतुरु (turuturu)
#    POS: None
#    Definition: चालणे cālaṇē to trip along
#
# 420. तुलना (tulanā)
#    POS: noun.feminine
#    Definition: comparison. ० करणे to compare
#
# 421. तुळस (tuḷasa)
#    POS: None
#    Definition: See तुळशी
#
# 422. तून (tūna)
#    POS: postposition
#    Definition: from, by, e.g., अमेरिके0 from (in) America. बैलगाडी0 by bullock cart
#
# 423. ते (tē)
#    POS: None
#    Definition: to, e.g., एक ० तीन from one to three
#
# 424. तेथे (tēthē)
#    POS: None
#    Definition: See तिथे
#
# 425. तेल (tēla)
#    POS: noun.neuter
#    Definition: oil. गोडे edible oil. कडू0 bitter oil, hence inedible oil
#
# 426. तोंड (tōṇḍa)
#    POS: noun.neuter
#    Definition: mouth. तोंडाला पाणी सुटणे for one's mouth to water. तोंडी लागणे to tangle with verbally. ० टाकणे to snap at, abuse
#
# 427. तोंड (tōṇḍa)
#    POS: noun.neuter
#    Definition: face. ० देणे to face
#
# 428. तोंडघशी (tōṇḍaghaśī)
#    POS: None
#    Definition: पडणे paḍaṇē to fall on (one's) face
#
# 429. तोंडसुख (tōṇḍasukha)
#    POS: None
#    Definition: घेणे ghēṇē to give someone a tongue-lashing
#
# 430. तोबरा (tōbarā)
#    POS: noun.masculine
#    Definition: feed-bag. ० भरणे cram (one's) mouth full
#
# 431. त्रागा (trāgā)
#    POS: None
#    Definition: करणे karaṇē 1. to inflict injury on oneself in order to protest another's behavior. 2. to protest strongly
#
# 432. त्रिमूर्ती (trimūrtī)
#    POS: noun.feminine
#    Definition: the united form of ब्रम्हा , विष्णू and शिव
#
# 433. थट्टामस्करी (thaṭṭāmaskarī)
#    POS: None
#    Definition: redupl. of थट्टा
#
# 434. थांग (thāṅga)
#    POS: noun.masculine
#    Definition: bottom, depth. ० लावणे to track down
#
# 435. थाप (thāpa)
#    POS: noun.feminine.e
#    Definition: lie. ० मारणे
#
# 436. थारा (thārā)
#    POS: noun.masculine
#    Definition: place. ० देणे to allow to stay, give refuge
#
# 437. थुंक (thuṅka)
#    POS: noun.feminine.i
#    Definition: spit. ० टाकणे to spit
#
# 438. थैमान (thaimāna)
#    POS: noun.neuter
#    Definition: raging. ० घालणे to rage
#
# 439. दखल (dakhala)
#    POS: noun.feminine
#    Definition: notice. ०घेणे to pay attention, heed. ०पात्र cognizable
#
# 440. दगा (dagā)
#    POS: noun.masculine
#    Definition: betrayal, letting down. ० देणे to betray. let down
#
# 441. दंडवत (daṇḍavata)
#    POS: noun.neuter
#    Definition: (in pl., m.) prostration of oneself before a god or person. ० घालणे to prostrate oneself
#
# 442. दडी (daḍī)
#    POS: None
#    Definition: मारणे māraṇē to hide (oneself)
#
# 443. दम (dama)
#    POS: noun.masculine
#    Definition: breath. ० धरणे to wait patiently. ० देणे to scold
#
# 444. दम (dama)
#    POS: noun.masculine
#    Definition: shortness of breath. ० लागणे to get out of breath
#
# 445. दमडी (damaḍī)
#    POS: noun.feminine
#    Definition: fourth of a पैसा according to the old coinage; hence: something of very little value
#
# 446. दया (dayā)
#    POS: noun.feminine
#    Definition: pity, mercy. ० येणे to feel pity
#
# 447. दवंडी (davaṇḍī)
#    POS: noun.feminine
#    Definition: public proclamation. ० पिटणे to proclaim by beating a drum
#
# 448. दशमी (daśamī)
#    POS: noun.feminine
#    Definition: a kind of पोळी or भाकरी
#
# 449. दळ (daḷa)
#    POS: noun.neuter
#    Definition: substance, pulp. Also see दल
#
# 450. दाखल (dākhala)
#    POS: adjective
#    Definition: inv. arrived. ० होणे to arrive, present oneself
#
# 451. दाढी (dāḍhī)
#    POS: noun.feminine
#    Definition: beard. ० करणे to shave
#
# 452. दाणदाण (dāṇadāṇa)
#    POS: adverb
#    Definition: noisily. ० पावले टाकणे to stomp
#
# 453. दात (dāta)
#    POS: noun.masculine
#    Definition: tooth. ० ओठ खाणे to express extreme resentment. ० असणे , धरणे to bear a grudge
#
# 454. दाद (dāda)
#    POS: noun.feminine.i
#    Definition: response. ० न देणे to defy
#
# 455. दाद (dāda)
#    POS: noun.feminine.i
#    Definition: redress. ० मागणे to ask for redress
#
# 456. दामटी (dāmaṭī)
#    POS: noun.feminine
#    Definition: small flat cake. ० वळणे to become thin
#
# 457. दिले (dilē)
#    POS: None
#    Definition: perf. of देणे
#
# 458. दिवस (divasa)
#    POS: noun.masculine
#    Definition: day. ० जाणे to be pregnant
#
# 459. दिवसा (divasā)
#    POS: adverb
#    Definition: during the day. ० ढवळ्या in broad daylight
#
# 460. दिवा (divā)
#    POS: noun.masculine
#    Definition: lamp, light. दिवे लावणे to make oneself notorious
#
# 461. दिव्य (divya)
#    POS: noun.neuter
#    Definition: ordeal. ० करणे to undergo an ordeal
#
# 462. दुग्धा (dugdhā)
#    POS: noun.masculine
#    Definition: indecision, uncertainty. दुग्ध्यात पडणे to be uncertain
#
# 463. दुरुत्तर (duruttara)
#    POS: noun.neuter
#    Definition: abusive or rude language. ० करणे to talk abusively or rudely
#
# 464. दुवा (duvā)
#    POS: noun.masculine
#    Definition: thanks. ० देणे to give thanks
#
# 465. दुष्काळ (duṣkāḷa)
#    POS: noun.masculine
#    Definition: famine, drought. ओला 0 famine caused by too much rain
#
# 466. दृष्ट (dṛṣṭa)
#    POS: noun.feminine.i
#    Definition: spell of the evil eye. ० लागणे to be under the spell of the evil eye
#
# 467. दृष्टोत्पत्ती (dṛṣṭōtpattī)
#    POS: noun.feminine
#    Definition: observation. ० स येणे to be observed
#
# 468. देवी (dēvī)
#    POS: noun.feminine
#    Definition: pl. smallpox. ० काढणे to vaccinate, get a vaccination
#
# 469. देहांत (dēhānta)
#    POS: noun.masculine
#    Definition: death. देहांताची शिक्षा capital punishment
#
# 470. दोरा (dōrā)
#    POS: noun.masculine
#    Definition: thread. ० घालणे to stitch, hem
#
# 471. द्वार (dvāra)
#    POS: noun.neuter
#    Definition: door. ० पाल doorkeeper
#
# 472. धक्का (dhakkā)
#    POS: noun.masculine
#    Definition: shock. ० बसणे to be shocked
#
# 473. धडकी (dhaḍakī)
#    POS: noun.feminine
#    Definition: fear, terror. ० भरणे to be terrified
#
# 474. धमकी (dhamakī)
#    POS: noun.feminine
#    Definition: threat. ० देणे to threaten
#
# 475. धस (dhasa)
#    POS: None
#    Definition: लागणे lāgaṇē to tear
#
# 476. धसका (dhasakā)
#    POS: noun.masculine
#    Definition: shock. ० बसणे to be shocked. ० घेणे to be frightened
#
# 477. धस्स (dhassa)
#    POS: None
#    Definition: होणे hōṇē to receive a shock
#
# 478. धाक (dhāka)
#    POS: noun.masculine
#    Definition: fear, awe. ० दाखवणे to threaten, intimidate
#
# 479. धाड (dhāḍa)
#    POS: noun.feminine.i
#    Definition: attack. ० भरणे , होणे to become sick. ० घालणे ro raid
#
# 480. धांदल (dhāndala)
#    POS: noun.feminine.i
#    Definition: hurry, haste. ० उडणे to be hurried, be rushed
#
# 481. धाप (dhāpa)
#    POS: noun.feminine.e
#    Definition: shortness of breath, gasp. ० लागणे , टाकणे to pant
#
# 482. धाबे (dhābē)
#    POS: noun.neuter
#    Definition: flat roof. ० दणाणणे to be terrified. धाब्यावर बसवणे to ignore, disobey
#
# 483. धाय (dhāya)
#    POS: None
#    Definition: मोकलून mōkalūna , रडणे raḍaṇē to weep loudly
#
# 484. धार (dhāra)
#    POS: noun.feminine.e
#    Definition: stream. ० लागणे to begin to flow in a stream. ० काढणे to milk
#
# 485. धार (dhāra)
#    POS: noun.feminine.e
#    Definition: edge. ० लावणे to sharpen. धारेवर धरणे to subject to severe criticism
#
# 486. धारण (dhāraṇa)
#    POS: None
#    Definition: करणे karaṇē to adopt
#
# 487. धाव (dhāva)
#    POS: noun.feminine.e
#    Definition: run. ० ठोकणे to start to run
#
# 488. धिंगाणा (dhiṅgāṇā)
#    POS: noun.masculine
#    Definition: rowdyism. ० घालणे to be rowdy
#
# 489. धीर (dhīra)
#    POS: noun.masculine
#    Definition: patience. ० धरणे to be patient. ० चेपणे for one's fear to be overcome
#
# 490. धुतले (dhutalē)
#    POS: None
#    Definition: perf. of धुणे
#
# 491. धुरी (dhurī)
#    POS: noun.feminine
#    Definition: fumigation. ० देणे to fumigate, smoke
#
# 492. धूम (dhūma)
#    POS: None
#    Definition: ठोकणे ṭhōkaṇē to run
#
# ...
#    POS: noun.feminine.i
#    Definition: spinning out. लांबणीवर टाकणे to delay, put off
#
# 788. लाल (lāla)
#    POS: None
#    Definition: भोपळा bhōpaḷā red gourd (similar to pumpkin)
#
# 789. लावणी (lāvaṇī)
#    POS: noun.feminine
#    Definition: love song in a तमाशा
#
# 790. लावणे (lāvaṇē)
#    POS: verb.transitive
#    Definition: to make (someone do something). मनाला लावून घेणे to take to heart
#
# 791. लाही (lāhī)
#    POS: noun.feminine
#    Definition: popped grain. अंगाची ० होणे to burn with heat or anger
#
# 792. लीला (līlā)
#    POS: noun.feminine
#    Definition: tricks. लीलेने easily
#
# 793. लुगडे (lugaḍē)
#    POS: noun.neuter
#    Definition: sari (esp. old-fashioned sari with border and पदर )
#
# 794. लोटांगण (lōṭāṅgaṇa)
#    POS: noun.neuter
#    Definition: rolling oneself over and over. ० घालणे to proceed in the direction of a god by rolling oneself over and over
#
# 795. लोळण (lōḷaṇa)
#    POS: noun.feminine.i
#    Definition: lying or rolling on the ground. ० घेणे to lie or roll on the ground
#
# 796. लौकर (laukara)
#    POS: None
#    Definition: See लवकर
#
# 797. लौकिक (laukika)
#    POS: adjective
#    Definition: inv. public. ०दृष्या as far as people are concerned
#
# 798. ल्यायले (lyāyalē)
#    POS: None
#    Definition: perf. of लेणे
#
# 799. वग (vaga)
#    POS: noun.masculine
#    Definition: a story or play constituting the main part of the तमाशा
#
# 800. वद्य (vadya)
#    POS: adjective
#    Definition: inv. dark. ० पक्ष dark fortnight of the lunar month
#
# 801. वय (vaya)
#    POS: noun.neuter
#    Definition: age. वयात येणे to reach puberty, come of age
#
# 802. वयस्कर (vayaskara)
#    POS: None
#    Definition: See वयस्क
#
# 803. वरवंटा (varavaṇṭā)
#    POS: noun.masculine
#    Definition: stone roller used for grinding on a पाटा
#
# 804. वंश (vaṃśa)
#    POS: noun.masculine
#    Definition: family line. ० वेल the vine of the family (metaphor for family line). वंशाचा दिवा heir (lit., lamp of the family line)
#
# 805. वाईटसाईट (vāīṭasāīṭa)
#    POS: None
#    Definition: redupl. of वाईट
#
# 806. वाकुल्या (vākulyā)
#    POS: None
#    Definition: दाखवणे dākhavaṇē to make faces at
#
# 807. वाख (vākha)
#    POS: None
#    Definition: See वाक
#
# 808. वाचा (vācā)
#    POS: noun.feminine
#    Definition: speech, voice. ० फुटणे to find tongue
#
# 809. वाजणे (vājaṇē)
#    POS: verb.intransitive
#    Definition: to make a sound. किती वाजले ? what time is it ? किती वाजता ? at what time ? थंडी 0 to feel cold
#
# 810. वाट (vāṭa)
#    POS: noun.feminine.e
#    Definition: way, path. ० पहाणे to wait for. वाटेला जाणे to keep after, bother, go after. वाटेला लावणे to send (someone) on (his) way
#
# 811. वाट (vāṭa)
#    POS: noun.feminine.e
#    Definition: outlet. ० काढणे to find a way
#
# 812. वाटणे (vāṭaṇē)
#    POS: verb.transitive
#    Definition: to grind on a पाटा
#
# 813. वाडगा (vāḍagā)
#    POS: noun.masculine
#    Definition: a big वाटी
#
# 814. वाफ (vāpha)
#    POS: noun.feminine.e
#    Definition: steam, vapor. तोंडाची ० दवडणे to waste one's breath
#
# 815. वाया (vāyā)
#    POS: adverb
#    Definition: emptily, fruitlessly. ० जाणे to go to waste
#
# 816. वायुभार (vāyubhāra)
#    POS: noun.masculine
#    Definition: atmospheric pressure. ० मापक यंत्र barometer
#
# 817. वाली (vālī)
#    POS: suffix
#    Definition: See वाला
#
# 818. वाले (vālē)
#    POS: suffix
#    Definition: See वाला
#
# 819. वाळीत (vāḷīta)
#    POS: None
#    Definition: टाकणे ṭākaṇē to ostracize, excommunicate
#
# 820. विकत (vikata)
#    POS: adjective
#    Definition: inv. bought. ० देणे to sell. ० घेणे to buy
#
# 821. विकोपाला (vikōpālā)
#    POS: None
#    Definition: जाणे jāṇē to go to the extreme
#
# 822. विडा (viḍā)
#    POS: noun.masculine
#    Definition: `pan' (betel leaf wrapped around betel nut and spices). ० उचलणे to take up a challenge
#
# 823. विराम (virāma)
#    POS: noun.masculine
#    Definition: pause, rest, stop. ०चिन्ह punctuation mark
#
# 824. विश्वास (viśvāsa)
#    POS: noun.masculine
#    Definition: faith, belief. ० टाकणे to rely on. ० ठेवणे , बसणे to believe
#
# 825. विसर (visara)
#    POS: noun.masculine
#    Definition: forgetfulness. ० पडणे to forget
#
# 826. विस्तव (vistava)
#    POS: noun.masculine
#    Definition: fire, hot coals. ० घालणे to fire, light
#
# 827. वेठ (vēṭha)
#    POS: noun.feminine.i
#    Definition: forced labor. ० मारणे to work carelessly
#
# 828. वेड (vēḍa)
#    POS: noun.neuter
#    Definition: obsessive idea. ० लागणे to go mad
#
# 829. वेणी (vēṇī)
#    POS: noun.feminine
#    Definition: braid, hair. ० घालणे to braid. ० फणी करणे to do one's hair
#
# 830. वेळ (vēḷa)
#    POS: noun.feminine.e
#    Definition: time. वेळेवर on time
#
# 831. वेळ (vēḷa)
#    POS: noun.feminine.e
#    Definition: (appointed) occasion. ० येणे for the necessity to arise
#
# 832. वेळ (vēḷa)
#    POS: noun.masculine
#    Definition: time (duration). ० असणे to have time. ० लावणे to be late, take time
#
# 833. व्यतीत (vyatīta)
#    POS: None
#    Definition: करणे karaṇē to pass
#
# 834. शक (śaka)
#    POS: noun.masculine
#    Definition: era. शके in the year (according to one of the traditional Indian calendars)
#
# 835. शंखध्वनी (śaṅkhadhvanī)
#    POS: noun.masculine
#    Definition: sound made by beating the mouth with the back of the hand (lit., sound made by blowing a conch-shell). See बोंब
#
# 836. शंढ (śaṇḍha)
#    POS: None
#    Definition: See षंढ
#
# 837. शरण (śaraṇa)
#    POS: None
#    Definition: जाणे jāṇē to surrender
#
# 838. शह (śaha)
#    POS: noun.masculine
#    Definition: check. ० देणे to check, foil
#
# 839. शिंकणे (śiṅkaṇē)
#    POS: verb.intransitive
#    Definition: to sneeze. माशी 0 used in reference to someone's finding a weak excuse for not doing something
#
# 840. शिंपली (śimpalī)
#    POS: noun.feminine
#    Definition: See शिंपला
#
# 841. शिमगा (śimagā)
#    POS: noun.masculine
#    Definition: a festival in the month of फाल्गुन . This is observed with unrestrained reverly and often antisocial pranks. People gather around bonfires and produce the sound called बोंब
#
# 842. शिरसाष्टांग (śirasāṣṭāṅga)
#    POS: None
#    Definition: नमस्कार namaskāra obeisance made by prostrating the body
#
# 843. शिवी (śivī)
#    POS: noun.feminine
#    Definition: abusive word. ० देणे to abuse
#
# 844. शिवीगाळ (śivīgāḷa)
#    POS: noun.feminine.i
#    Definition: redupl. of शिवी
#
# 845. शिस्त (śista)
#    POS: noun.feminine.i
#    Definition: discipline. ० लावणे to discipline
#
# 846. शीळ (śīḷa)
#    POS: noun.feminine.e
#    Definition: whistle. ०घालणे to whistle
#
# 847. शुक्ल (śukla)
#    POS: adjective
#    Definition: inv. white, bright. पक्ष the bright fortnight of the month
#
# 848. शुद्ध (śuddha)
#    POS: adjective
#    Definition: correct. ०पक्ष the bright fortnight of the month
#
# 849. शुद्धी (śuddhī)
#    POS: noun.feminine
#    Definition: consciousness. ०वर येणे to regain consciousness. ०त असणे to be in one's senses
#
# 850. शेकणे (śēkaṇē)
#    POS: verb.transitive
#    Definition: to heat with a hot water bottle or heating pad, foment. अंगावर 0 to bear the brunt
#
# 851. शेखी (śēkhī)
#    POS: noun.feminine
#    Definition: boast. ० मिरवणे to boast
#
# 852. शेवगा (śēvagā)
#    POS: noun.masculine
#    Definition: a mold for preparing शेव
#
# 853. शेवटी (śēvaṭī)
#    POS: None
#    Definition: loc. of शेवट . finally, at last
#
# 854. शोध (śōdha)
#    POS: noun.masculine
#    Definition: search. ० करणे , घेणे to search for. ० लावणे to discover, invent
#
# 855. शॉक (śôka)
#    POS: noun.masculine
#    Definition: shock. ० बसणे to get a shock
#
# 856. श्रीकृष्ण (śrīkṛṣṇa)
#    POS: noun.masculine
#    Definition: a god. (one of the manifestations of विष्णू )
#
# 857. श्वास (śvāsa)
#    POS: noun.masculine
#    Definition: breath. ० लागणे to pant. ० टाकणे to sigh, pant
#
# 858. षड्रिपू (ṣaḍripū)
#    POS: noun.masculine
#    Definition: pl. the six enemies of the soul (viz., काम , क्रोध , लोभ , मोह , मद , मत्सर )
#
# 859. स.न.वि.वि. (sa.na.vi.vi.)
#    POS: None
#    Definition: abbrev of. सप्रेम नमस्कार विनंती विशेष (the usual salutation at the beginning of a letter)
#
# 860. संगती (saṅgatī)
#    POS: noun.feminine
#    Definition: connection, consistency, harmony. ० लावणे , लागणे to understand the connection or meaning
#
# 861. सजा (sajā)
#    POS: noun.feminine
#    Definition: punishment. ० देणे to sentence
#
# 862. सती (satī)
#    POS: noun.feminine
#    Definition: wife who burns herself on her husband's funeral pyre. ० जाणे to burn oneself on one's husband's funeral pyre
#
# 863. संधान (sandhāna)
#    POS: noun.neuter
#    Definition: connection. ० बांधणे to form a connection
#
# 864. संप (sampa)
#    POS: noun.masculine
#    Definition: strike. ० करणे , संपावर जाणे to strike, go on strike
#
# 865. संपणे (sampaṇē)
#    POS: verb.intransitive
#    Definition: to be finished, be used up. संपत येणे to be nearly finished
#
# 866. संपुष्टात (sampuṣṭāta)
#    POS: None
#    Definition: येणे yēṇē to end
#
# 867. संभाळणे (sambhāḷaṇē)
#    POS: verb.transitive
#    Definition: to observe, follow. संभाळून घेणे to protect, refrain from censure
#
# 868. समरस (samarasa)
#    POS: adjective
#    Definition: inv. of the same essence. ० होणे to have empathy for
#
# 869. समुद्र (samudra)
#    POS: noun.masculine
#    Definition: sea. ०सपाटी sea level
#
# 870. सरकारी (sarakārī)
#    POS: adjective
#    Definition: inv. governmental. ० वकील public prosecutor
#
# 871. सरसे (sarasē)
#    POS: postposition
#    Definition: See सरशी
#
# 872. संसार (saṃsāra)
#    POS: noun.masculine
#    Definition: household. ० मांडणे to set up house
#
# 873. सहन (sahana)
#    POS: adjective
#    Definition: inv. borne. ० करणे , होणे to bear, put up with
#
# 874. साकळणे (sākaḷaṇē)
#    POS: None
#    Definition: See साखळणे
#
# 875. सांगड (sāṅgaḍa)
#    POS: noun.feminine.i
#    Definition: linking, connection. ० घालणे to link
#
# 876. सांगणे (sāṅgaṇē)
#    POS: verb.transitive
#    Definition: (irrreg.) to tell. सांगून येणे to be offered in marriage
#
# 877. सांगितले (sāṅgitalē)
#    POS: None
#    Definition: perf. of सांगणे
#
# 878. सांबारे (sāmbārē)
#    POS: None
#    Definition: See सांबार
#
# 879. सांभाळ (sāmbhāḷa)
#    POS: None
#    Definition: See संभाळ
#
# 880. सामानसुमान (sāmānasumāna)
#    POS: None
#    Definition: redupl. of सामान
#
# 881. सामीलल (sāmīlala)
#    POS: None
#    Definition: होणे hōṇē to join
#
# 882. सामोरे (sāmōrē)
#    POS: adverb
#    Definition: in front. ० येणे to come to meet, receive
#
# 883. सारखे (sārakhē)
#    POS: postposition
#    Definition: like, -able, e. g., बघण्यासारखे worth seeing
#
# 884. सुख (sukha)
#    POS: noun.neuter
#    Definition: something that brings happiness. सुखाने
#
# 885. सुखी (sukhī)
#    POS: adjective
#    Definition: inv. contented, happy. खाऊनपिऊन 0 well off
#
# 886. सुटे (suṭē)
#    POS: adjective
#    Definition: separate. ० पैसे loose change
#
# 887. सुरुंग (suruṅga)
#    POS: noun.masculine
#    Definition: blast. ० लावणे to blast
#
# 888. सुरुवात (suruvāta)
#    POS: None
#    Definition: See सुरवात
#
# 889. सुस्कारा (suskārā)
#    POS: noun.masculine
#    Definition: sigh. ० सोडणे to sigh
#
# 890. सुज (suja)
#    POS: noun.feminine.e
#    Definition: swelling. ० येणे to swell
#
# 891. सूड (sūḍa)
#    POS: noun.masculine
#    Definition: revenge. ० घेणे to take revenge
#
# 892. सूर (sūra)
#    POS: noun.masculine
#    Definition: dive. सुरात in tune
#
# 893. सैपाक (saipāka)
#    POS: None
#    Definition: See स्वयंपाक
#
# 894. सोइस्कर (sōiskara)
#    POS: None
#    Definition: See सोयिस्कर
#
# 895. सोवळे (sōvaḷē)
#    POS: noun.neuter
#    Definition: ritually pure clothing. सोवळी बाई widow
#
# 896. सोक्षमोक्ष (sōkṣamōkṣa)
#    POS: noun.masculine
#    Definition: final settlement. ० लावणे to settle finally
#
# 897. सौ. (sau.)
#    POS: None
#    Definition: abbrev. of सौभाग्यवती
#
# 898. स्तोम (stōma)
#    POS: noun.neuter
#    Definition: undue importance. ० माजवणे to give undue importance
#
# 899. स्फुरण (sphuraṇa)
#    POS: noun.neuter
#    Definition: infusion of courage. ० येणे , चढणे to be infused with courage
#
# 900. स्फुरण (sphuraṇa)
#    POS: noun.neuter
#    Definition: itch (to do). ० पावणे to itch (to do)
#
# 901. स्फोटक (sphōṭaka)
#    POS: adjective
#    Definition: inv. explosive. ०द्रव्य explosive substance
#
# 902. स्वच्छंदी (svacchandī)
#    POS: adjective
#    Definition: inv. See स्वच्छंद
#
# 903. स्वप्न (svapna)
#    POS: noun.neuter
#    Definition: dream. ० पडणे to dream. ० पाहणे to see a dream
#
# 904. स्वार (svāra)
#    POS: noun.masculine
#    Definition: rider. ० होणे to mount
#
# 905. स्वैपाक (svaipāka)
#    POS: None
#    Definition: See स्वयंपाक
#
# 906. हजर (hajara)
#    POS: adjective
#    Definition: present. ० राहणे to be present
#
# 907. हजेरी (hajērī)
#    POS: noun.feminine
#    Definition: to give a dressing down. ० लावणे to put in an appearance
#
# 908. हटणे (haṭaṇē)
#    POS: verb.intransitive
#    Definition: to move back, retreat. हटून बसणे to become obstinate
#
# 909. हट्ट (haṭṭa)
#    POS: noun.masculine
#    Definition: obstinate demand. ० करणे , धरणे to make an obstinate demand
#
# 910. हबका (habakā)
#    POS: None
#    Definition: See हपका
#
# 911. हंबरडा (hambaraḍā)
#    POS: noun.masculine
#    Definition: bellow. ० फोडणे to bellow
#
# 912. हमी (hamī)
#    POS: noun.feminine
#    Definition: guarantee. ० घेणे to assume responsibility. ० देणे to give a guarantee
#
# 913. हरकत (harakata)
#    POS: noun.feminine.i
#    Definition: objection, opposition. ० घेणे to object
#
# 914. हरिण (hariṇa)
#    POS: None
#    Definition: See हरण , def. 1
#
# 915. हलके (halakē)
#    POS: adverb
#    Definition: softly. ० हलके gradually. हलक्या कानाचे credulous
#
# 916. हवा (havā)
#    POS: noun.feminine
#    Definition: air. ० खाणे to get some air
#
# 917. हशा (haśā)
#    POS: noun.masculine
#    Definition: laughter. ० पिकणे for laughter to burst out
#
# 918. हसणे (hasaṇē)
#    POS: verb.intransitive
#    Definition: to smile. हसून घालवणे to laugh off
#
# 919. हसे (hasē)
#    POS: noun.neuter
#    Definition: ridicule. ० होणे to become a laughingstock
#
# 920. हळू (haḷū)
#    POS: adverb
#    Definition: slowly. ० हळू gradually
#
# 921. हाक (hāka)
#    POS: noun.feminine.e
#    Definition: call. ० मारणे to call
#
# 922. हाड (hāḍa)
#    POS: noun.neuter
#    Definition: bone. जिभेला ० नसणे to be tactless in speech
#
# 923. हात (hāta)
#    POS: noun.masculine
#    Definition: arm-length. ० जोडणे to supplicate. ० टाकणे to lay hands upon. ० टेकणे to give up. ० दाखवणे to punish. ० दाबणे to bribe. ० देणे to help. ० मारणे to eat heartily. ० राखून carefully, sparingly. हाती असणे to be in one's power
#
# 924. हातपाय (hātapāya)
#    POS: noun.masculine
#    Definition: pl. hands and feet, arms and legs. ० गाळणे to lose heart. हातापाया पडणे to supplicate. ० हलवणे to make an effort
#
# 925. हातभार (hātabhāra)
#    POS: noun.masculine
#    Definition: help. ० लावणे to help
#
# 926. हाय (hāya)
#    POS: interjection
#    Definition: an exclamation of pain ० खाणे to lose hope
#
# 927. हार (hāra)
#    POS: noun.feminine
#    Definition: defeat. ० खाणे , होणे to be defeated
#
# 928. हालणे (hālaṇē)
#    POS: None
#    Definition: See हलणे
#
# 929. हालवणे (hālavaṇē)
#    POS: None
#    Definition: See हलवणे
#
# 930. हिकमत (hikamata)
#    POS: noun.feminine.i
#    Definition: stratagem. ० लढवणे to employ a stratagem
#
# 931. हिडीसफिडीस (hiḍīsaphiḍīsa)
#    POS: None
#    Definition: करणे karaṇē to treat with scorn and lack of affection
#
# 932. हिय्या (hiyyā)
#    POS: noun.masculine
#    Definition: resolution. ० करणे to resolve, gather one's courage
#
# 933. हिशेब (hiśēba)
#    POS: noun.masculine
#    Definition: calculation. ० करणे to calculate
#
# 934. हिशेब (hiśēba)
#    POS: noun.masculine
#    Definition: accounts. ० ठेवणे to keep accounts
#
# 935. हिशोब (hiśōba)
#    POS: None
#    Definition: See हिशेब
#
# 936. हुंकार (huṅkāra)
#    POS: noun.masculine
#    Definition: the periodic utterance of the sound हुं as a signal of attention while listening to a narration
#
# 937. हुकूम (hukūma)
#    POS: noun.masculine
#    Definition: order. ० देणे , सोडणे to give an order
#
# 938. हुजत (hujata)
#    POS: noun.feminine.i
#    Definition: argument. ० घालणे to be argumentative
#
# 939. हुज्जत (hujjata)
#    POS: None
#    Definition: See हुजत
#
# 940. हुडहुडी (huḍahuḍī)
#    POS: noun.feminine
#    Definition: shivering. ० भरणे to shiver, feel cold
#
# 941. हुंदका (hundakā)
#    POS: noun.masculine
#    Definition: sob. ० देणे , येणे to sob
#
# 942. हुरहुर (hurahura)
#    POS: noun.feminine.i
#    Definition: longing. ० लागणे to be anxious, long for
#
# 943. हुलकावणी (hulakāvaṇī)
#    POS: noun.feminine
#    Definition: dodging. ० देणे to dodge
#
# 944. हूल (hūla)
#    POS: noun.feminine.i
#    Definition: rumor. ० उठणे for a rumor to start
#
# 945. हेलकावा (hēlakāvā)
#    POS: noun.masculine
#    Definition: swing, oscillation. ० देणे , खाणे to swing
#
# 946. होकार (hōkāra)
#    POS: noun.masculine
#    Definition: assent. ० देणे to give assent
#
# 947. होते (hōtē)
#    POS: None
#    Definition: past tense of असणे
#
# 948. होळी (hōḷī)
#    POS: noun.feminine
#    Definition: See शिमगा

# %%
find_see = next((e for e in data if e['headword_devanagari'] == 'हरिण'), None)
find_see
# Out:
# OrderedDict([('entry_id', 'berntsen_हरिण_166'),
#              ('headword_devanagari', 'हरिण'),
#              ('headword_romanized', 'hariṇa'),
#              ('full_entry', 'हरिण hariṇa See हरण , def. 1.'),
#              ('source_page', 166),
#              ('definitions',
#               [{'definition': 'See हरण , def. 1',
#                 'pos_display': None,
#                 'number': None,
#                 'pos': None,
#                 'gender': None,
#                 'declension_class': None,
#                 'see_also': {'entry_id': 'berntsen_हरण_166',
#                  'headword_devanagari': 'हरण',
#                  'headword_romanized': 'haraṇa',
#                  'full_entry': 'हरण haraṇa n. 1. deer. 2. making away with.',
#                  'source_page': 166,
#                  'definitions': [{'definition': 'deer',
#                    'pos_display': 'n.',
#                    'number': 1,
#                    'pos': 'noun.neuter',
#                    'gender': 'neuter',
#                    'declension_class': None,
#                    'see_also': None},
#                   {'definition': 'making away with',
#                    'pos_display': 'n.',
#                    'number': 2,
#                    'pos': 'noun.neuter',
#                    'gender': 'neuter',
#                    'declension_class': None,
#                    'see_also': None}]}}])])

# %%
print(json.dumps(data[695], ensure_ascii=False, indent=2))
# Out:
# {
#   "entry_id": "berntsen_उंचावणे_12",
#   "headword_devanagari": "उंचावणे",
#   "headword_romanized": "uñcāvaṇē",
#   "full_entry": "उंचावणे uñcāvaṇē v.i. to rise, be raised. v.t. to raise.",
#   "source_page": 12,
#   "definitions": [
#     {
#       "definition": "to rise, be raised",
#       "pos_display": "v.i.",
#       "number": null,
#       "pos": "verb.intransitive",
#       "gender": null,
#       "declension_class": null,
#       "see_also": null
#     },
#     {
#       "definition": "to raise",
#       "pos_display": "v.t.",
#       "number": null,
#       "pos": "verb.transitive",
#       "gender": null,
#       "declension_class": null,
#       "see_also": null
#     }
#   ]
# }
